# %%
import pickle
import pandas as pd
import numpy as np
import optuna

#     optuna_hyperparameters_per_dataset.py
#  -> analysis_hyperparameters.ipynb
#  -> benchmark_best_hyperparameters.py
#  -> analysis_hyperparameters_runs.ipynb

# %%
storage = "sqlite:///optuna_results_parameter_tuning_full_gate.sqlite3"
#sqlite:///optuna_results_parameter_tuning_2D_gate.sqlite3

# %%
studies = optuna.study.get_all_study_summaries(storage=storage)

# %%
loaded_study = optuna.load_study(study_name=studies[0].study_name, storage=storage)
df = loaded_study.trials_dataframe()
for key, value in loaded_study.system_attrs.items():
    df[key] = value
for study in studies[1:]:
    loaded_study = optuna.load_study(study_name=study.study_name , storage=storage)
    df_new = loaded_study.trials_dataframe()
    for key, value in loaded_study.system_attrs.items():
        df_new[key] = value
    df = pd.concat([df, df_new])
df.reset_index(inplace=True, drop=True)

# %%
df.columns
# Out:
# Index(['number', 'value', 'datetime_start', 'datetime_complete', 'duration',
#        'params_init_learning_rate', 'params_learning_rate_decay',
#        'params_max_depth', 'params_n_experts', 'params_optimization_method',
#        'params_use_2_dim_gate_based_on', 'params_use_posterior',
#        'user_attrs_accuracy_train', 'user_attrs_accuracy_val',
#        'user_attrs_std_train', 'user_attrs_std_val', 'state', 'Data X',
#        'Data y', 'initialization_method', 'params_alpha', 'params_beta',
#        'params_gamma', 'params_mean_precision_prior',
#        'params_weight_concentration_prior',
#        'params_weight_concentration_prior_type', 'params_weight_cutoff'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.934402 2021-06-28 08:31:42.575957 2021-06-28 08:31:44.482651
#
#                 duration  params_init_learning_rate  \
# 0 0 days 00:00:01.906694                 126.893719
#
#    params_learning_rate_decay  params_max_depth  params_n_experts  \
# 0                    0.979807                 2                 3
#
#   params_optimization_method  ...             Data X              Data y  \
# 0           lasso_regression  ...  banknote_input.pd  banknote_target.pd
#
#    initialization_method  params_alpha  params_beta  params_gamma  \
# 0                    str           NaN          NaN           NaN
#
#   params_mean_precision_prior params_weight_concentration_prior  \
# 0                         NaN                               NaN
#
#   params_weight_concentration_prior_type params_weight_cutoff
# 0                                    NaN                  NaN
#
# [1 rows x 27 columns]

# %%
df.initialization_method.value_counts()
# Out:
# str              1200
# KDTmeans_init    1200
# Kmeans_init      1200
# BGM_init         1200
# Name: initialization_method, dtype: int64

# %%
np.unique(df.initialization_method)
# Out:
# array(['BGM_init', 'KDTmeans_init', 'Kmeans_init', 'str'], dtype=object)

# %%
np.unique(df["Data X"])
# Out:
# array(['abalone_input.pd', 'bank_input.pd', 'banknote_input.pd',
#        'breast_cancer_input.np', 'cars_input.pd',
#        'contraceptive_input.pd', 'hrss_input.pd', 'iris_input.pd',
#        'occupancy_input.pd', 'pdm6_input.pd', 'steel_input.pd',
#        'students_input.pd'], dtype=object)

# %%
top = 10
df_best = pd.DataFrame()
for dataset in np.unique(df["Data X"]):
    df_new = df[df["Data X"] == dataset].sort_values(by=["user_attrs_accuracy_val"], ascending=False).head(top)
    df_best = pd.concat([df_best, df_new])
df_best.reset_index(inplace=True, drop=True)

# %%
df_best.shape
# Out:
# (120, 27)

# %%
df_best.head(2)
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0      93  0.745514 2021-06-29 12:07:27.597629 2021-06-29 12:07:32.297630
# 1      13  0.744554 2021-06-29 12:01:27.584103 2021-06-29 12:01:32.140103
#
#                 duration  params_init_learning_rate  \
# 0 0 days 00:00:04.700001                  77.143561
# 1 0 days 00:00:04.556000                  91.218285
#
#    params_learning_rate_decay  params_max_depth  params_n_experts  \
# 0                    0.996708                 2                 3
# 1                    0.990082                 2                 3
#
#         params_optimization_method  ...            Data X             Data y  \
# 0  least_squares_linear_regression  ...  abalone_input.pd  abalone_target.pd
# 1  least_squares_linear_regression  ...  abalone_input.pd  abalone_target.pd
#
#    initialization_method  params_alpha  params_beta  params_gamma  \
# 0                    str           NaN          NaN           NaN
# 1                    str           NaN          NaN           NaN
#
#   params_mean_precision_prior params_weight_concentration_prior  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
#
#   params_weight_concentration_prior_type params_weight_cutoff
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
#
# [2 rows x 27 columns]

# %%
#pickle.dump(df_best, open("dataframes/df_top10_hyperparameters_per_dataset_full_gate.pd", "wb"))
pickle.dump(df_best, open("dataframes/df_top10_hyperparameters_per_dataset_2D_gate.pd", "wb"))

# %%
df.groupby(["Data X"]).mean()
# Out:
#                         number     value  params_init_learning_rate  \
# Data X
# abalone_input.pd          49.5  0.718313                 100.870177
# bank_input.pd             49.5  0.894801                  84.822159
# banknote_input.pd         49.5  0.985703                  91.835222
# breast_cancer_input.np    49.5  0.923378                  77.863780
# cars_input.pd             49.5  0.830913                  73.803925
# contraceptive_input.pd    49.5  0.482352                  89.062544
# hrss_input.pd             49.5  0.772794                  84.051263
# iris_input.pd             49.5  0.941639                  72.551168
# occupancy_input.pd        49.5  0.990486                 100.005012
# pdm6_input.pd             49.5  0.971841                  90.668083
# steel_input.pd            49.5  0.633857                 101.063913
# students_input.pd         49.5  0.435034                  83.708225
#
#                         params_learning_rate_decay  params_max_depth  \
# Data X
# abalone_input.pd                          0.991120               2.0
# bank_input.pd                             0.985161               2.0
# banknote_input.pd                         0.988745               2.0
# breast_cancer_input.np                    0.989836               2.0
# cars_input.pd                             0.990044               2.0
# contraceptive_input.pd                    0.987160               2.0
# hrss_input.pd                             0.989719               2.0
# iris_input.pd                             0.984680               2.0
# occupancy_input.pd                        0.992146               2.0
# pdm6_input.pd                             0.985388               2.0
# steel_input.pd                            0.990218               2.0
# students_input.pd                         0.989402               2.0
#
#                         params_n_experts  params_use_posterior  \
# Data X
# abalone_input.pd                     3.0                0.1025
# bank_input.pd                        3.0                0.4150
# banknote_input.pd                    3.0                0.1000
# breast_cancer_input.np               3.0                0.8350
# cars_input.pd                        3.0                0.1625
# contraceptive_input.pd               3.0                0.3700
# hrss_input.pd                        3.0                0.2000
# iris_input.pd                        3.0                0.3200
# occupancy_input.pd                   3.0                0.1425
# pdm6_input.pd                        3.0                0.6300
# steel_input.pd                       3.0                0.1075
# students_input.pd                    3.0                0.6025
#
#                         user_attrs_accuracy_train  user_attrs_accuracy_val  \
# Data X
# abalone_input.pd                         0.738198                 0.718313
# bank_input.pd                            0.908060                 0.894801
# banknote_input.pd                        0.992063                 0.985703
# breast_cancer_input.np                   0.964506                 0.923378
# cars_input.pd                            0.841654                 0.830913
# contraceptive_input.pd                   0.518784                 0.482352
# hrss_input.pd                            0.774240                 0.772794
# iris_input.pd                            0.989928                 0.941639
# occupancy_input.pd                       0.992330                 0.990486
# pdm6_input.pd                            0.974281                 0.971841
# steel_input.pd                           0.673722                 0.633857
# students_input.pd                        0.528176                 0.435034
#
#                         user_attrs_std_train  user_attrs_std_val  \
# Data X
# abalone_input.pd                    0.009060            0.013313
# bank_input.pd                       0.001192            0.017108
# banknote_input.pd                   0.002498            0.005923
# breast_cancer_input.np              0.005518            0.018881
# cars_input.pd                       0.012895            0.019184
# contraceptive_input.pd              0.020712            0.024101
# hrss_input.pd                       0.002667            0.004664
# iris_input.pd                       0.005979            0.031358
# occupancy_input.pd                  0.001242            0.002180
# pdm6_input.pd                       0.001198            0.002664
# steel_input.pd                      0.019654            0.024118
# students_input.pd                   0.013203            0.042654
#
#                         params_alpha  params_beta  params_gamma  \
# Data X
# abalone_input.pd            1.762906     0.216682      0.206034
# bank_input.pd               2.980814     0.261024      0.333999
# banknote_input.pd           1.955231     0.131670      0.142040
# breast_cancer_input.np      2.391755     0.315951      0.396414
# cars_input.pd               2.311915     0.290541      0.376067
# contraceptive_input.pd      2.621254     0.186496      0.351942
# hrss_input.pd               3.289162     0.190816      0.305248
# iris_input.pd               2.187940     0.272645      0.209092
# occupancy_input.pd          2.604595     0.258040      0.335174
# pdm6_input.pd               3.176146     0.149032      0.341776
# steel_input.pd              3.253139     0.213718      0.317925
# students_input.pd           2.222016     0.206763      0.205405
#
#                         params_mean_precision_prior  \
# Data X
# abalone_input.pd                           0.416497
# bank_input.pd                              0.680125
# banknote_input.pd                          0.437000
# breast_cancer_input.np                     0.641454
# cars_input.pd                              0.734330
# contraceptive_input.pd                     0.373333
# hrss_input.pd                              0.685352
# iris_input.pd                              0.390111
# occupancy_input.pd                         0.283890
# pdm6_input.pd                              0.622306
# steel_input.pd                             0.648736
# students_input.pd                          0.504879
#
#                         params_weight_concentration_prior  \
# Data X
# abalone_input.pd                                 0.653325
# bank_input.pd                                    0.660794
# banknote_input.pd                                0.597199
# breast_cancer_input.np                           0.416285
# cars_input.pd                                    0.572777
# contraceptive_input.pd                           0.388996
# hrss_input.pd                                    0.422043
# iris_input.pd                                    0.785381
# occupancy_input.pd                               0.682469
# pdm6_input.pd                                    0.537459
# steel_input.pd                                   0.604038
# students_input.pd                                0.433143
#
#                         params_weight_cutoff
# Data X
# abalone_input.pd                         0.0
# bank_input.pd                            0.0
# banknote_input.pd                        0.0
# breast_cancer_input.np                   0.0
# cars_input.pd                            0.0
# contraceptive_input.pd                   0.0
# hrss_input.pd                            0.0
# iris_input.pd                            0.0
# occupancy_input.pd                       0.0
# pdm6_input.pd                            0.0
# steel_input.pd                           0.0
# students_input.pd                        0.0

# %%
df["params_use_2_dim_gate_based_on"].value_counts(dropna=False)
# Out:
# NaN    4800
# Name: params_use_2_dim_gate_based_on, dtype: int64
