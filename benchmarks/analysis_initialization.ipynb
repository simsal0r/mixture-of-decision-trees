# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_pickle("dataframes/df_initialization_methods.pd")
df
# Out:
#                    dataset  n_features  \
# 0   breast_cancer_input.np          10
# 1            iris_input.pd           4
# 2           steel_input.pd          27
# 3         abalone_input.pd           8
# 4   contraceptive_input.pd           9
# 5            cars_input.pd           6
# 6        students_input.pd          11
# 7           adult_input.pd          14
# 8            bank_input.pd          20
# 9            hrss_input.pd          18
# 10      occupancy_input.pd           5
# 11           pdm6_input.pd           6
# 12       banknote_input.pd           4
#
#     feature_importance_lr_max_Random_init_train  \
# 0                                      0.964849
# 1                                      0.987093
# 2                                      0.662821
# 3                                      0.731865
# 4                                      0.571532
# 5                                      0.799113
# 6                                      0.544942
# 7                                      0.837246
# 8                                      0.908133
# 9                                      0.767754
# 10                                     0.990610
# 11                                     0.972440
# 12                                     0.974976
#
#     feature_importance_lr_max_Random_init_test  \
# 0                                     0.920583
# 1                                     0.949111
# 2                                     0.638328
# 3                                     0.716734
# 4                                     0.541750
# 5                                     0.791551
# 6                                     0.468972
# 7                                     0.834726
# 8                                     0.903452
# 9                                     0.767063
# 10                                    0.988555
# 11                                    0.971040
# 12                                    0.968659
#
#     feature_importance_lr_max_Random_init_train_std  \
# 0                                          0.006634
# 1                                          0.009544
# 2                                          0.029478
# 3                                          0.007791
# 4                                          0.012844
# 5                                          0.013771
# 6                                          0.020667
# 7                                          0.006990
# 8                                          0.001890
# 9                                          0.003119
# 10                                         0.001344
# 11                                         0.001511
# 12                                         0.009615
#
#     feature_importance_lr_max_Random_init_test_std  \
# 0                                         0.019573
# 1                                         0.043275
# 2                                         0.037411
# 3                                         0.014922
# 4                                         0.018261
# 5                                         0.019811
# 6                                         0.048652
# 7                                         0.011842
# 8                                         0.013726
# 9                                         0.006399
# 10                                        0.002797
# 11                                        0.003682
# 12                                        0.008642
#
#     feature_importance_lr_max_Random_init_train_i_0  \
# 0                                          0.941452
# 1                                          0.982301
# 2                                          0.563874
# 3                                          0.696138
# 4                                          0.481448
# 5                                          0.785494
# 6                                          0.494000
# 7                                          0.796747
# 8                                          0.898838
# 9                                          0.764407
# 10                                         0.989031
# 11                                         0.973867
# 12                                         0.922255
#
#     feature_importance_lr_max_Random_init_train_i_1  \
# 0                                          0.941452
# 1                                          0.982301
# 2                                          0.559066
# 3                                          0.697415
# 4                                          0.488688
# 5                                          0.785494
# 6                                          0.494000
# 7                                          0.796747
# 8                                          0.898870
# 9                                          0.764407
# 10                                         0.989031
# 11                                         0.973867
# 12                                         0.893100
#
#     feature_importance_lr_max_Random_init_train_i_2  \
# 0                                          0.939110
# 1                                          0.982301
# 2                                          0.559066
# 3                                          0.699968
# 4                                          0.505882
# 5                                          0.785494
# 6                                          0.494000
# 7                                          0.796747
# 8                                          0.898903
# 9                                          0.764407
# 10                                         0.989031
# 11                                         0.973867
# 12                                         0.899903
#
#     feature_importance_lr_max_Random_init_train_i_3  ...  \
# 0                                          0.950820  ...
# 1                                          0.982301  ...
# 2                                          0.559066  ...
# 3                                          0.704117  ...
# 4                                          0.531222  ...
# 5                                          0.785494  ...
# 6                                          0.494000  ...
# 7                                          0.796747  ...
# 8                                          0.898741  ...
# 9                                          0.764407  ...
# 10                                         0.989031  ...
# 11                                         0.973867  ...
# 12                                         0.911565  ...
#
#     None_BGM_init_train_i_90  None_BGM_init_train_i_91  \
# 0                   0.962529                  0.962529
# 1                   0.982301                  0.982301
# 2                   0.637363                  0.637363
# 3                   0.749761                  0.749761
# 4                   0.513122                  0.513122
# 5                   0.806327                  0.806327
# 6                   0.534000                  0.534000
# 7                   0.824905                  0.824905
# 8                   0.912466                  0.912466
# 9                   0.774727                  0.774783
# 10                  0.988540                  0.988540
# 11                  0.971600                  0.971600
# 12                  0.992225                  0.992225
#
#     None_BGM_init_train_i_92  None_BGM_init_train_i_93  \
# 0                   0.960187                  0.962529
# 1                   0.982301                  0.982301
# 2                   0.637363                  0.638049
# 3                   0.749761                  0.749761
# 4                   0.513122                  0.513122
# 5                   0.806327                  0.806327
# 6                   0.534000                  0.534000
# 7                   0.824905                  0.824905
# 8                   0.912466                  0.912531
# 9                   0.774783                  0.774783
# 10                  0.988540                  0.988540
# 11                  0.971600                  0.971600
# 12                  0.992225                  0.992225
#
#     None_BGM_init_train_i_94  None_BGM_init_train_i_95  \
# 0                   0.962529                  0.962529
# 1                   0.982301                  0.982301
# 2                   0.638049                  0.638049
# 3                   0.749761                  0.749122
# 4                   0.513122                  0.513122
# 5                   0.807870                  0.810957
# 6                   0.534000                  0.534000
# 7                   0.824905                  0.824905
# 8                   0.912531                  0.912531
# 9                   0.774783                  0.774783
# 10                  0.988540                  0.988540
# 11                  0.971600                  0.971600
# 12                  0.992225                  0.992225
#
#     None_BGM_init_train_i_96  None_BGM_init_train_i_97  \
# 0                   0.962529                  0.962529
# 1                   0.982301                  0.982301
# 2                   0.638049                  0.638049
# 3                   0.749122                  0.749122
# 4                   0.513122                  0.513122
# 5                   0.812500                  0.814815
# 6                   0.534000                  0.534000
# 7                   0.824905                  0.824905
# 8                   0.912531                  0.912531
# 9                   0.774839                  0.774839
# 10                  0.988540                  0.988540
# 11                  0.971600                  0.971600
# 12                  0.992225                  0.992225
#
#     None_BGM_init_train_i_98  None_BGM_init_train_i_99
# 0                   0.962529                  0.962529
# 1                   0.982301                  0.982301
# 2                   0.638049                  0.638049
# 3                   0.748803                  0.748803
# 4                   0.513122                  0.513122
# 5                   0.817130                  0.819444
# 6                   0.534000                  0.534000
# 7                   0.824905                  0.824905
# 8                   0.912531                  0.912531
# 9                   0.774896                  0.774896
# 10                  0.988540                  0.988540
# 11                  0.971600                  0.971600
# 12                  0.992225                  0.992225
#
# [13 rows x 834 columns]

# %%
df.columns
# Out:
# Index(['dataset', 'n_features', 'feature_importance_lr_max_Random_init_train',
#        'feature_importance_lr_max_Random_init_test',
#        'feature_importance_lr_max_Random_init_train_std',
#        'feature_importance_lr_max_Random_init_test_std',
#        'feature_importance_lr_max_Random_init_train_i_0',
#        'feature_importance_lr_max_Random_init_train_i_1',
#        'feature_importance_lr_max_Random_init_train_i_2',
#        'feature_importance_lr_max_Random_init_train_i_3',
#        ...
#        'None_BGM_init_train_i_90', 'None_BGM_init_train_i_91',
#        'None_BGM_init_train_i_92', 'None_BGM_init_train_i_93',
#        'None_BGM_init_train_i_94', 'None_BGM_init_train_i_95',
#        'None_BGM_init_train_i_96', 'None_BGM_init_train_i_97',
#        'None_BGM_init_train_i_98', 'None_BGM_init_train_i_99'],
#       dtype='object', length=834)

# %%
selector = ['dataset',
           'n_features',
           'feature_importance_lr_max_Random_init_test',
           'feature_importance_lr_max_Random_init_test_std',
           'feature_importance_lr_max_Random_init_train_i_0',
           'feature_importance_lr_max_Random_init_train_i_9',
           'feature_importance_lr_max_Random_init_train_i_99',
           'feature_importance_lr_max_Kmeans_init_test',
           'feature_importance_lr_max_Kmeans_init_test_std',
           'feature_importance_lr_max_Kmeans_init_train_i_0',
           'feature_importance_lr_max_Kmeans_init_train_i_9',
           'feature_importance_lr_max_Kmeans_init_train_i_99',  
           'feature_importance_lr_max_KDTmeans_init_test',
           'feature_importance_lr_max_KDTmeans_init_test_std',
           'feature_importance_lr_max_KDTmeans_init_train_i_0',
           'feature_importance_lr_max_KDTmeans_init_train_i_9',
           'feature_importance_lr_max_KDTmeans_init_train_i_99',
           'feature_importance_lr_max_BGM_init_test',
           'feature_importance_lr_max_BGM_init_test_std',
           'feature_importance_lr_max_BGM_init_train_i_0',
           'feature_importance_lr_max_BGM_init_train_i_9',
           'feature_importance_lr_max_BGM_init_train_i_99',
           'None_Random_init_test',
           'None_Random_init_test_std',
           'None_Random_init_train_i_0',
           'None_Random_init_train_i_9',
           'None_Random_init_train_i_99',
           'None_Kmeans_init_test',
           'None_Kmeans_init_test_std',
           'None_Kmeans_init_train_i_0',
           'None_Kmeans_init_train_i_9',
           'None_Kmeans_init_train_i_99',  
           'None_KDTmeans_init_test',
           'None_KDTmeans_init_test_std',
           'None_KDTmeans_init_train_i_0',
           'None_KDTmeans_init_train_i_9',
           'None_KDTmeans_init_train_i_99',
           'None_BGM_init_test',
           'None_BGM_init_test_std',
           'None_BGM_init_train_i_0',
           'None_BGM_init_train_i_9',
           'None_BGM_init_train_i_99'            
           ]

# %%
df[selector]
# Out:
#                    dataset  n_features  \
# 0   breast_cancer_input.np          10
# 1            iris_input.pd           4
# 2           steel_input.pd          27
# 3         abalone_input.pd           8
# 4   contraceptive_input.pd           9
# 5            cars_input.pd           6
# 6        students_input.pd          11
# 7           adult_input.pd          14
# 8            bank_input.pd          20
# 9            hrss_input.pd          18
# 10      occupancy_input.pd           5
# 11           pdm6_input.pd           6
# 12       banknote_input.pd           4
#
#     feature_importance_lr_max_Random_init_test  \
# 0                                     0.920583
# 1                                     0.949111
# 2                                     0.638328
# 3                                     0.716734
# 4                                     0.541750
# 5                                     0.791551
# 6                                     0.468972
# 7                                     0.834726
# 8                                     0.903452
# 9                                     0.767063
# 10                                    0.988555
# 11                                    0.971040
# 12                                    0.968659
#
#     feature_importance_lr_max_Random_init_test_std  \
# 0                                         0.019573
# 1                                         0.043275
# 2                                         0.037411
# 3                                         0.014922
# 4                                         0.018261
# 5                                         0.019811
# 6                                         0.048652
# 7                                         0.011842
# 8                                         0.013726
# 9                                         0.006399
# 10                                        0.002797
# 11                                        0.003682
# 12                                        0.008642
#
#     feature_importance_lr_max_Random_init_train_i_0  \
# 0                                          0.941452
# 1                                          0.982301
# 2                                          0.563874
# 3                                          0.696138
# 4                                          0.481448
# 5                                          0.785494
# 6                                          0.494000
# 7                                          0.796747
# 8                                          0.898838
# 9                                          0.764407
# 10                                         0.989031
# 11                                         0.973867
# 12                                         0.922255
#
#     feature_importance_lr_max_Random_init_train_i_9  \
# 0                                          0.953162
# 1                                          0.982301
# 2                                          0.558379
# 3                                          0.717204
# 4                                          0.538462
# 5                                          0.785494
# 6                                          0.494000
# 7                                          0.779418
# 8                                          0.898870
# 9                                          0.764295
# 10                                         0.989031
# 11                                         0.973867
# 12                                         0.925170
#
#     feature_importance_lr_max_Random_init_train_i_99  \
# 0                                           0.955504
# 1                                           1.000000
# 2                                           0.644231
# 3                                           0.737632
# 4                                           0.554751
# 5                                           0.785494
# 6                                           0.494000
# 7                                           0.838874
# 8                                           0.908647
# 9                                           0.769482
# 10                                          0.989031
# 11                                          0.974133
# 12                                          0.970845
#
#     feature_importance_lr_max_Kmeans_init_test  \
# 0                                     0.936039
# 1                                     0.945341
# 2                                     0.577532
# 3                                     0.697294
# 4                                     0.530884
# 5                                     0.784722
# 6                                     0.475911
# 7                                     0.835574
# 8                                     0.909556
# 9                                     0.767570
# 10                                    0.988432
# 11                                    0.970900
# 12                                    0.964577
#
#     feature_importance_lr_max_Kmeans_init_test_std  \
# 0                                         0.020428
# 1                                         0.029882
# 2                                         0.023644
# 3                                         0.015817
# 4                                         0.021787
# 5                                         0.016900
# 6                                         0.044202
# 7                                         0.012517
# 8                                         0.002053
# 9                                         0.005204
# 10                                        0.002398
# 11                                        0.003849
# 12                                        0.012850
#
#     feature_importance_lr_max_Kmeans_init_train_i_0  ...  \
# 0                                          0.960187  ...
# 1                                          0.991150  ...
# 2                                          0.606456  ...
# 3                                          0.714331  ...
# 4                                          0.551131  ...
# 5                                          0.786265  ...
# 6                                          0.564000  ...
# 7                                          0.840200  ...
# 8                                          0.910297  ...
# 9                                          0.771851  ...
# 10                                         0.988867  ...
# 11                                         0.969067  ...
# 12                                         0.966958  ...
#
#     None_KDTmeans_init_test  None_KDTmeans_init_test_std  \
# 0                  0.927935                     0.023134
# 1                  0.939900                     0.032886
# 2                  0.616373                     0.033391
# 3                  0.698491                     0.015367
# 4                  0.452402                     0.024415
# 5                  0.806713                     0.013166
# 6                  0.452880                     0.053856
# 7                  0.836065                     0.004509
# 8                  0.904647                     0.004852
# 9                  0.771554                     0.006652
# 10                 0.989316                     0.002658
# 11                 0.969640                     0.001828
# 12                 0.983965                     0.006743
#
#     None_KDTmeans_init_train_i_0  None_KDTmeans_init_train_i_9  \
# 0                       0.946136                      0.960187
# 1                       1.000000                      1.000000
# 2                       0.620192                      0.616758
# 3                       0.703798                      0.705075
# 4                       0.491403                      0.491403
# 5                       0.816358                      0.816358
# 6                       0.514000                      0.516000
# 7                       0.835691                      0.835691
# 8                       0.907772                      0.907772
# 9                       0.772471                      0.772471
# 10                      0.989031                      0.989194
# 11                      0.972267                      0.972267
# 12                      0.957240                      0.968902
#
#     None_KDTmeans_init_train_i_99  None_BGM_init_test  None_BGM_init_test_std  \
# 0                        0.978923            0.919184                0.022159
# 1                        1.000000            0.957397                0.028292
# 2                        0.646978            0.622468                0.027115
# 3                        0.704756            0.711419                0.021251
# 4                        0.491403            0.473197                0.030221
# 5                        0.816358            0.818403                0.037693
# 6                        0.518000            0.397565                0.063550
# 7                        0.835691            0.808733                0.017779
# 8                        0.907772            0.865242                0.072268
# 9                        0.772471            0.770209                0.007058
# 10                       0.994106            0.990642                0.002550
# 11                       0.972267            0.971300                0.003210
# 12                       0.995141            0.985714                0.006706
#
#     None_BGM_init_train_i_0  None_BGM_init_train_i_9  None_BGM_init_train_i_99
# 0                  0.941452                 0.955504                  0.962529
# 1                  0.982301                 0.982301                  0.982301
# 2                  0.561813                 0.576923                  0.638049
# 3                  0.715608                 0.720396                  0.748803
# 4                  0.513122                 0.513122                  0.513122
# 5                  0.782407                 0.782407                  0.819444
# 6                  0.534000                 0.534000                  0.534000
# 7                  0.824684                 0.824684                  0.824905
# 8                  0.912531                 0.912175                  0.912531
# 9                  0.774219                 0.774501                  0.774896
# 10                 0.988048                 0.988540                  0.988540
# 11                 0.971600                 0.971600                  0.971600
# 12                 0.969874                 0.986395                  0.992225
#
# [13 rows x 42 columns]

# %%
gate_methods = ["feature_importance_lr_max" , "None"]
init_methods = ["Random_init","Kmeans_init","KDTmeans_init","BGM_init"]
datasets = df.dataset.unique()

# %%
str1 = ""
p1 = "placeholder"
for dataset in datasets:            
        for im in init_methods:
            if dataset != p1:
                str1 += "\\hline\r\n"
                str1 += "\\multirow{4}{2cm}{" + dataset.split("_")[0] +"}"
            p1 = dataset
            str1 += " & "
            str1 += im.split("_")[0] + " & "
            for gm in gate_methods: 
                column = [str(gm + "_" + im + "_test")]
                str1 += ("%.2f" % round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0")
                column = [str(gm + "_" + im + "_test_std")]
                str1 += " $\\pm$" + str(round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0") + " & "
                column = [str(gm + "_" + im + "_train_i_0")]
                str1 += ("%.2f" % round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0") + " & "
                column = [str(gm + "_" + im + "_train_i_9")]
                str1 += ("%.2f" % round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0") + " & "
                column = [str(gm + "_" + im + "_train_i_99")]
                str1 += ("%.2f" % round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0") + " & "
            str1 = str1[:-2]
            str1 +=  "\\\\"
            str1 += "\r\n"
print(str1)
# Out:
# \hline
# \multirow{4}{2cm}{breast} & Random & .92 $\pm$.02 & .94 & .95 & .96 & .93 $\pm$.02 & .94 & .96 & .98 \\
#  & Kmeans & .94 $\pm$.02 & .96 & .96 & .98 & .93 $\pm$.02 & .95 & .96 & .97 \\
#  & KDTmeans & .93 $\pm$.03 & .96 & .97 & .98 & .93 $\pm$.02 & .95 & .96 & .98 \\
#  & BGM & .93 $\pm$.02 & .95 & .96 & .97 & .92 $\pm$.02 & .94 & .96 & .96 \\
# \hline
# \multirow{4}{2cm}{iris} & Random & .95 $\pm$.04 & .98 & .98 & 1.00 & .95 $\pm$.03 & .97 & .97 & 1.00 \\
#  & Kmeans & .95 $\pm$.03 & .99 & 1.00 & 1.00 & .95 $\pm$.03 & .99 & .99 & .99 \\
#  & KDTmeans & .94 $\pm$.03 & 1.00 & 1.00 & .99 & .94 $\pm$.03 & 1.00 & 1.00 & 1.00 \\
#  & BGM & .95 $\pm$.03 & .97 & .97 & 1.00 & .96 $\pm$.03 & .98 & .98 & .98 \\
# \hline
# \multirow{4}{2cm}{steel} & Random & .64 $\pm$.04 & .56 & .56 & .64 & .67 $\pm$.02 & .60 & .68 & .71 \\
#  & Kmeans & .58 $\pm$.02 & .61 & .61 & .61 & .61 $\pm$.04 & .55 & .56 & .56 \\
#  & KDTmeans & .58 $\pm$.03 & .60 & .60 & .61 & .62 $\pm$.03 & .62 & .62 & .65 \\
#  & BGM & .65 $\pm$.04 & .59 & .61 & .64 & .62 $\pm$.03 & .56 & .58 & .64 \\
# \hline
# \multirow{4}{2cm}{abalone} & Random & .72 $\pm$.01 & .70 & .72 & .74 & .73 $\pm$.01 & .69 & .70 & .74 \\
#  & Kmeans & .70 $\pm$.02 & .71 & .72 & .72 & .70 $\pm$.02 & .70 & .70 & .72 \\
#  & KDTmeans & .70 $\pm$.01 & .71 & .70 & .70 & .70 $\pm$.02 & .70 & .71 & .70 \\
#  & BGM & .72 $\pm$.01 & .69 & .71 & .73 & .71 $\pm$.02 & .72 & .72 & .75 \\
# \hline
# \multirow{4}{2cm}{contraceptive} & Random & .54 $\pm$.02 & .48 & .54 & .55 & .52 $\pm$.03 & .54 & .56 & .58 \\
#  & Kmeans & .53 $\pm$.02 & .55 & .55 & .55 & .46 $\pm$.03 & .43 & .43 & .43 \\
#  & KDTmeans & .53 $\pm$.02 & .56 & .56 & .56 & .45 $\pm$.02 & .49 & .49 & .49 \\
#  & BGM & .53 $\pm$.02 & .57 & .57 & .57 & .47 $\pm$.03 & .51 & .51 & .51 \\
# \hline
# \multirow{4}{2cm}{cars} & Random & .79 $\pm$.02 & .79 & .79 & .79 & .89 $\pm$.02 & .80 & .85 & .91 \\
#  & Kmeans & .78 $\pm$.02 & .79 & .79 & .79 & .80 $\pm$.02 & .81 & .81 & .81 \\
#  & KDTmeans & .79 $\pm$.02 & .77 & .77 & .77 & .81 $\pm$.01 & .82 & .82 & .82 \\
#  & BGM & .79 $\pm$.02 & .78 & .78 & .78 & .82 $\pm$.04 & .78 & .78 & .82 \\
# \hline
# \multirow{4}{2cm}{students} & Random & .47 $\pm$.05 & .49 & .49 & .49 & .40 $\pm$.07 & .50 & .56 & .60 \\
#  & Kmeans & .48 $\pm$.04 & .56 & .56 & .56 & .46 $\pm$.03 & .55 & .56 & .57 \\
#  & KDTmeans & .47 $\pm$.05 & .55 & .55 & .55 & .45 $\pm$.05 & .51 & .52 & .52 \\
#  & BGM & .47 $\pm$.05 & .49 & .49 & .49 & .40 $\pm$.06 & .53 & .53 & .53 \\
# \hline
# \multirow{4}{2cm}{adult} & Random & .83 $\pm$.01 & .80 & .78 & .84 & .80 $\pm$.04 & .81 & .84 & .85 \\
#  & Kmeans & .84 $\pm$.01 & .84 & .84 & .84 & .83 $\pm$.02 & .84 & .84 & .84 \\
#  & KDTmeans & .84 $\pm$.0 & .84 & .84 & .84 & .84 $\pm$.0 & .84 & .84 & .84 \\
#  & BGM & .84 $\pm$.0 & .83 & .83 & .84 & .81 $\pm$.02 & .82 & .82 & .82 \\
# \hline
# \multirow{4}{2cm}{bank} & Random & .90 $\pm$.01 & .90 & .90 & .91 & .90 $\pm$.01 & .90 & .91 & .91 \\
#  & Kmeans & .91 $\pm$.0 & .91 & .91 & .91 & .90 $\pm$.0 & .91 & .91 & .91 \\
#  & KDTmeans & .91 $\pm$.0 & .91 & .91 & .91 & .90 $\pm$.0 & .91 & .91 & .91 \\
#  & BGM & .90 $\pm$.01 & .91 & .91 & .91 & .87 $\pm$.07 & .91 & .91 & .91 \\
# \hline
# \multirow{4}{2cm}{hrss} & Random & .77 $\pm$.01 & .76 & .76 & .77 & .77 $\pm$.01 & .77 & .77 & .77 \\
#  & Kmeans & .77 $\pm$.01 & .77 & .77 & .77 & .77 $\pm$.01 & .77 & .77 & .77 \\
#  & KDTmeans & .77 $\pm$.0 & .77 & .77 & .77 & .77 $\pm$.01 & .77 & .77 & .77 \\
#  & BGM & .77 $\pm$.01 & .77 & .77 & .77 & .77 $\pm$.01 & .77 & .77 & .77 \\
# \hline
# \multirow{4}{2cm}{occupancy} & Random & .99 $\pm$.0 & .99 & .99 & .99 & .99 $\pm$.0 & .99 & .99 & .99 \\
#  & Kmeans & .99 $\pm$.0 & .99 & .99 & .99 & .99 $\pm$.0 & .99 & .99 & .99 \\
#  & KDTmeans & .99 $\pm$.0 & .99 & .99 & .99 & .99 $\pm$.0 & .99 & .99 & .99 \\
#  & BGM & .99 $\pm$.0 & .99 & .99 & .99 & .99 $\pm$.0 & .99 & .99 & .99 \\
# \hline
# \multirow{4}{2cm}{pdm6} & Random & .97 $\pm$.0 & .97 & .97 & .97 & .97 $\pm$.0 & .97 & .97 & .98 \\
#  & Kmeans & .97 $\pm$.0 & .97 & .97 & .97 & .97 $\pm$.0 & .97 & .97 & .97 \\
#  & KDTmeans & .97 $\pm$.0 & .97 & .97 & .97 & .97 $\pm$.0 & .97 & .97 & .97 \\
#  & BGM & .97 $\pm$.0 & .97 & .97 & .97 & .97 $\pm$.0 & .97 & .97 & .97 \\
# \hline
# \multirow{4}{2cm}{banknote} & Random & .97 $\pm$.01 & .92 & .93 & .97 & .99 $\pm$.01 & .90 & .98 & 1.00 \\
#  & Kmeans & .96 $\pm$.01 & .97 & .97 & .97 & .98 $\pm$.01 & .97 & .97 & .99 \\
#  & KDTmeans & .97 $\pm$.01 & .98 & .98 & .98 & .98 $\pm$.01 & .96 & .97 & 1.00 \\
#  & BGM & .95 $\pm$.02 & .98 & .98 & .98 & .99 $\pm$.01 & .97 & .99 & .99 \\

# %%
df[selector]
# Out:
#                    dataset  n_features  \
# 0   breast_cancer_input.np          10
# 1            iris_input.pd           4
# 2           steel_input.pd          27
# 3         abalone_input.pd           8
# 4   contraceptive_input.pd           9
# 5            cars_input.pd           6
# 6        students_input.pd          11
# 7           adult_input.pd          14
# 8            bank_input.pd          20
# 9            hrss_input.pd          18
# 10      occupancy_input.pd           5
# 11           pdm6_input.pd           6
# 12       banknote_input.pd           4
#
#     feature_importance_lr_max_Random_init_test  \
# 0                                     0.920583
# 1                                     0.949111
# 2                                     0.638328
# 3                                     0.716734
# 4                                     0.541750
# 5                                     0.791551
# 6                                     0.468972
# 7                                     0.834726
# 8                                     0.903452
# 9                                     0.767063
# 10                                    0.988555
# 11                                    0.971040
# 12                                    0.968659
#
#     feature_importance_lr_max_Random_init_test_std  \
# 0                                         0.019573
# 1                                         0.043275
# 2                                         0.037411
# 3                                         0.014922
# 4                                         0.018261
# 5                                         0.019811
# 6                                         0.048652
# 7                                         0.011842
# 8                                         0.013726
# 9                                         0.006399
# 10                                        0.002797
# 11                                        0.003682
# 12                                        0.008642
#
#     feature_importance_lr_max_Random_init_train_i_0  \
# 0                                          0.941452
# 1                                          0.982301
# 2                                          0.563874
# 3                                          0.696138
# 4                                          0.481448
# 5                                          0.785494
# 6                                          0.494000
# 7                                          0.796747
# 8                                          0.898838
# 9                                          0.764407
# 10                                         0.989031
# 11                                         0.973867
# 12                                         0.922255
#
#     feature_importance_lr_max_Random_init_train_i_9  \
# 0                                          0.953162
# 1                                          0.982301
# 2                                          0.558379
# 3                                          0.717204
# 4                                          0.538462
# 5                                          0.785494
# 6                                          0.494000
# 7                                          0.779418
# 8                                          0.898870
# 9                                          0.764295
# 10                                         0.989031
# 11                                         0.973867
# 12                                         0.925170
#
#     feature_importance_lr_max_Random_init_train_i_99  \
# 0                                           0.955504
# 1                                           1.000000
# 2                                           0.644231
# 3                                           0.737632
# 4                                           0.554751
# 5                                           0.785494
# 6                                           0.494000
# 7                                           0.838874
# 8                                           0.908647
# 9                                           0.769482
# 10                                          0.989031
# 11                                          0.974133
# 12                                          0.970845
#
#     feature_importance_lr_max_Kmeans_init_test  \
# 0                                     0.936039
# 1                                     0.945341
# 2                                     0.577532
# 3                                     0.697294
# 4                                     0.530884
# 5                                     0.784722
# 6                                     0.475911
# 7                                     0.835574
# 8                                     0.909556
# 9                                     0.767570
# 10                                    0.988432
# 11                                    0.970900
# 12                                    0.964577
#
#     feature_importance_lr_max_Kmeans_init_test_std  \
# 0                                         0.020428
# 1                                         0.029882
# 2                                         0.023644
# 3                                         0.015817
# 4                                         0.021787
# 5                                         0.016900
# 6                                         0.044202
# 7                                         0.012517
# 8                                         0.002053
# 9                                         0.005204
# 10                                        0.002398
# 11                                        0.003849
# 12                                        0.012850
#
#     feature_importance_lr_max_Kmeans_init_train_i_0  ...  \
# 0                                          0.960187  ...
# 1                                          0.991150  ...
# 2                                          0.606456  ...
# 3                                          0.714331  ...
# 4                                          0.551131  ...
# 5                                          0.786265  ...
# 6                                          0.564000  ...
# 7                                          0.840200  ...
# 8                                          0.910297  ...
# 9                                          0.771851  ...
# 10                                         0.988867  ...
# 11                                         0.969067  ...
# 12                                         0.966958  ...
#
#     None_KDTmeans_init_test  None_KDTmeans_init_test_std  \
# 0                  0.927935                     0.023134
# 1                  0.939900                     0.032886
# 2                  0.616373                     0.033391
# 3                  0.698491                     0.015367
# 4                  0.452402                     0.024415
# 5                  0.806713                     0.013166
# 6                  0.452880                     0.053856
# 7                  0.836065                     0.004509
# 8                  0.904647                     0.004852
# 9                  0.771554                     0.006652
# 10                 0.989316                     0.002658
# 11                 0.969640                     0.001828
# 12                 0.983965                     0.006743
#
#     None_KDTmeans_init_train_i_0  None_KDTmeans_init_train_i_9  \
# 0                       0.946136                      0.960187
# 1                       1.000000                      1.000000
# 2                       0.620192                      0.616758
# 3                       0.703798                      0.705075
# 4                       0.491403                      0.491403
# 5                       0.816358                      0.816358
# 6                       0.514000                      0.516000
# 7                       0.835691                      0.835691
# 8                       0.907772                      0.907772
# 9                       0.772471                      0.772471
# 10                      0.989031                      0.989194
# 11                      0.972267                      0.972267
# 12                      0.957240                      0.968902
#
#     None_KDTmeans_init_train_i_99  None_BGM_init_test  None_BGM_init_test_std  \
# 0                        0.978923            0.919184                0.022159
# 1                        1.000000            0.957397                0.028292
# 2                        0.646978            0.622468                0.027115
# 3                        0.704756            0.711419                0.021251
# 4                        0.491403            0.473197                0.030221
# 5                        0.816358            0.818403                0.037693
# 6                        0.518000            0.397565                0.063550
# 7                        0.835691            0.808733                0.017779
# 8                        0.907772            0.865242                0.072268
# 9                        0.772471            0.770209                0.007058
# 10                       0.994106            0.990642                0.002550
# 11                       0.972267            0.971300                0.003210
# 12                       0.995141            0.985714                0.006706
#
#     None_BGM_init_train_i_0  None_BGM_init_train_i_9  None_BGM_init_train_i_99
# 0                  0.941452                 0.955504                  0.962529
# 1                  0.982301                 0.982301                  0.982301
# 2                  0.561813                 0.576923                  0.638049
# 3                  0.715608                 0.720396                  0.748803
# 4                  0.513122                 0.513122                  0.513122
# 5                  0.782407                 0.782407                  0.819444
# 6                  0.534000                 0.534000                  0.534000
# 7                  0.824684                 0.824684                  0.824905
# 8                  0.912531                 0.912175                  0.912531
# 9                  0.774219                 0.774501                  0.774896
# 10                 0.988048                 0.988540                  0.988540
# 11                 0.971600                 0.971600                  0.971600
# 12                 0.969874                 0.986395                  0.992225
#
# [13 rows x 42 columns]

# %%
metrics = ["feature_importance_lr_max_{}_test",
           "feature_importance_lr_max_{}_train_i_0",
           "feature_importance_lr_max_{}_train_i_9",
           "feature_importance_lr_max_{}_train_i_99",
           "None_{}_test",
           "None_{}_train_i_0",
           "None_{}_train_i_9",
           "None_{}_train_i_99",
          ]

# %%
df_sums = pd.DataFrame(init_methods)
for m in metrics:
    sumcolumns = []
    for im in init_methods:
        sumcolumns.append(m.format(im))
    df_sums[m] = df[selector].sum()[sumcolumns].values / df[selector].sum()[sumcolumns].values[0]   
    
df_sums
# Out:
#                0 feature_importance_lr_max_{}_test  \
# 0    Random_init                                 1
# 1    Kmeans_init                          0.992716
# 2  KDTmeans_init                          0.994554
# 3       BGM_init                          0.999718
#
#   feature_importance_lr_max_{}_train_i_0  \
# 0                                      1
# 1                                1.03216
# 2                                1.03245
# 3                                1.01837
#
#   feature_importance_lr_max_{}_train_i_9  \
# 0                                      1
# 1                                1.02742
# 2                                1.02632
# 3                                1.01728
#
#   feature_importance_lr_max_{}_train_i_99 None_{}_test None_{}_train_i_0  \
# 0                                       1            1                 1
# 1                                 1.00395     0.986164           1.00379
# 2                                 1.00141     0.985501           1.01283
# 3                                 1.00213     0.979939           1.00756
#
#   None_{}_train_i_9 None_{}_train_i_99
# 0                 1                  1
# 1          0.974378           0.956057
# 2          0.982218            0.96601
# 3          0.979469           0.968652

# %%
#Exclude datasets where nothing happens
df2 = df[selector]
df2[df2.dataset.isin(["hrss_input.pd"])==False]
for m in metrics:
    sumcolumns = []
    for im in init_methods:
        sumcolumns.append(m.format(im))
    df_sums[m] = df2.sum()[sumcolumns].values / df2.sum()[sumcolumns].values[0]   
    
df_sums
# Out:
#                0 feature_importance_lr_max_{}_test  \
# 0    Random_init                                 1
# 1    Kmeans_init                          0.992716
# 2  KDTmeans_init                          0.994554
# 3       BGM_init                          0.999718
#
#   feature_importance_lr_max_{}_train_i_0  \
# 0                                      1
# 1                                1.03216
# 2                                1.03245
# 3                                1.01837
#
#   feature_importance_lr_max_{}_train_i_9  \
# 0                                      1
# 1                                1.02742
# 2                                1.02632
# 3                                1.01728
#
#   feature_importance_lr_max_{}_train_i_99 None_{}_test None_{}_train_i_0  \
# 0                                       1            1                 1
# 1                                 1.00395     0.986164           1.00379
# 2                                 1.00141     0.985501           1.01283
# 3                                 1.00213     0.979939           1.00756
#
#   None_{}_train_i_9 None_{}_train_i_99
# 0                 1                  1
# 1          0.974378           0.956057
# 2          0.982218            0.96601
# 3          0.979469           0.968652

# %%
df_sums = pd.DataFrame(init_methods)
for m in metrics:
    sumcolumns = []
    for im in init_methods:
        sumcolumns.append(m.format(im))
    df_sums[m] = df[selector].sum()[sumcolumns].values - df[selector].sum()[sumcolumns].values[0]   
    
df_sums
# Out:
#                0 feature_importance_lr_max_{}_test  \
# 0    Random_init                                 0
# 1    Kmeans_init                        -0.0761911
# 2  KDTmeans_init                        -0.0569656
# 3       BGM_init                       -0.00295333
#
#   feature_importance_lr_max_{}_train_i_0  \
# 0                                      0
# 1                               0.330912
# 2                               0.333937
# 3                               0.188997
#
#   feature_importance_lr_max_{}_train_i_9  \
# 0                                      0
# 1                               0.284046
# 2                               0.272693
# 3                               0.178979
#
#   feature_importance_lr_max_{}_train_i_99 None_{}_test None_{}_train_i_0  \
# 0                                       0            0                 0
# 1                               0.0419561    -0.145308          0.039379
# 2                               0.0149808    -0.152275          0.133304
# 3                               0.0226413    -0.210685         0.0786054
#
#   None_{}_train_i_9 None_{}_train_i_99
# 0                 0                  0
# 1         -0.275265           -0.48372
# 2         -0.191038          -0.374164
# 3          -0.22057          -0.345083

# %%
str1 = "\\hline\r\n"
str1 += "\\multirow{4}{2cm}{" + "sum" +"}"
for index, row in df_sums.iterrows():
    for element in row:
        if type(element) == str: 
            str1 += " & " + element.split("_")[0] + " & "
        else:
            str1 += ("%.2f" % round(element, 2)).replace("0.",".") + " & "
    str1 = str1[:-2]        
    str1 +=  "\\\\"
    str1 += "\r\n"
    
print(str1)
# Out:
# \hline
# \multirow{4}{2cm}{sum} & Random & .00 & .00 & .00 & .00 & .00 & .00 & .00 & .00 \\
#  & Kmeans & -.08 & .33 & .28 & .04 & -.15 & .04 & -.28 & -.48 \\
#  & KDTmeans & -.06 & .33 & .27 & .01 & -.15 & .13 & -.19 & -.37 \\
#  & BGM & -.00 & .19 & .18 & .02 & -.21 & .08 & -.22 & -.35 \\

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
plt.style.use('ggplot')
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['font.size'] = 12

COLOR = 'black'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR

# %%
gate_methods = ["feature_importance_lr_max" , "None"]
init_methods = ["Random_init","Kmeans_init","KDTmeans_init","BGM_init"]

# %%
df.dataset.unique()
# Out:
# array(['breast_cancer_input.np', 'iris_input.pd', 'steel_input.pd',
#        'abalone_input.pd', 'contraceptive_input.pd', 'cars_input.pd',
#        'students_input.pd', 'adult_input.pd', 'bank_input.pd',
#        'hrss_input.pd', 'occupancy_input.pd', 'pdm6_input.pd',
#        'banknote_input.pd'], dtype=object)

# %%
datasets1 = [
             'iris_input.pd',
             'breast_cancer_input.np',
             'cars_input.pd',
             'abalone_input.pd',
             'steel_input.pd',
             'students_input.pd',
             'contraceptive_input.pd',
]
datasets2 = [
             'occupancy_input.pd',
             'banknote_input.pd',
             'pdm6_input.pd',
             'bank_input.pd',
             'adult_input.pd',
             'hrss_input.pd',
]

# %%
colormap = { 
    'iris_input.pd': "#8EBA42",
    'breast_cancer_input.np' : "#FBC15E" ,
    'cars_input.pd' : "#B97357",
    'abalone_input.pd': "#348ABD",
    'steel_input.pd': "#988ED5",
    'contraceptive_input.pd' : "#E24A33" ,
    'students_input.pd' : "#81D0DB",
    
    'occupancy_input.pd' : "#348ABD",
    'banknote_input.pd' : "#81D0DB",
    'pdm6_input.pd' : "#FBC15E",
    'bank_input.pd' : "#8EBA42",
    'adult_input.pd' :"#E24A33",
    'hrss_input.pd' : "#988ED5",
}

# %%
for dataset_group in [datasets1, datasets2]:
    displayed_iterations=100
    fig = plt.gcf()
    fig.set_size_inches(10, 4)
    iterations = np.arange(displayed_iterations)
    for dataset in dataset_group:
        accuracies = []
        for i in range(displayed_iterations):
            accuracies.append(df[df.dataset == dataset]["feature_importance_lr_max_Random_init_train_i_" + str(i)].values[0])
        plt.plot(iterations,accuracies,linewidth=1,linestyle='--',color=colormap[dataset])
        accuracies = []
        for i in range(displayed_iterations):
            accuracies.append(df[df.dataset == dataset]["feature_importance_lr_max_BGM_init_train_i_" + str(i)].values[0])
        plt.plot(iterations,accuracies,linewidth=1,linestyle='-',color=colormap[dataset],label=dataset.split("_")[0])
    plt.ylabel("training accuracy", fontsize=12)
    plt.xlabel("iteration", fontsize=12)
    l1 = plt.legend(bbox_to_anchor=(1, 1.02), loc="upper left")

    legend_elements = [Line2D([0], [0], color='grey', linestyle='-', label='initialization'),
                       Line2D([0], [0], color='grey', linestyle='--', label='random')]
    ax = plt.gca()
    ax.legend(handles=legend_elements, bbox_to_anchor=(1, -0.02), loc="lower left")
    ax.add_artist(l1)   
    
    #plt.savefig("plots/test.pdf", bbox_inches="tight")
    plt.show()
                                                    #

# %%
def translator(word):
    if word == "feature_importance_lr_max":
        return "2D "
    elif word == "None":
        return "f. "
    else:
        return "error"

# %%
# Save all
for gm in gate_methods:
    for im in init_methods:
        for dataset_group in [datasets1, datasets2]:
            displayed_iterations=100
            fig = plt.gcf()
            fig.set_size_inches(4.65, 3.3)
            iterations = np.arange(displayed_iterations)
            for dataset in dataset_group:
                accuracies = []
                for i in range(displayed_iterations):
                    accuracies.append(df[df.dataset == dataset]["{}_Random_init_train_i_".format(gm) + str(i)].values[0])
                plt.plot(iterations,accuracies,linewidth=1.5,linestyle='--',color=colormap[dataset])
                accuracies = []
                for i in range(displayed_iterations):
                    accuracies.append(df[df.dataset == dataset]["{}_{}_train_i_".format(gm,im) + str(i)].values[0])
                plt.plot(iterations,accuracies,linewidth=1.5,linestyle='-',color=colormap[dataset],label=dataset.split("_")[0])
            plt.ylabel("training accuracy", fontsize=12)
            plt.xlabel("iteration", fontsize=12)
            l1 = plt.legend(bbox_to_anchor=(1, 1.02), loc="upper left")

            legend_elements = [Line2D([0], [0], color='grey', linestyle='-', label=translator(gm) + im.split("_")[0] ),
                               Line2D([0], [0], color='grey', linestyle='--', label=translator(gm) + "random")]
            ax = plt.gca()
            ax.legend(handles=legend_elements, bbox_to_anchor=(1, -0.02), loc="lower left")
            ax.add_artist(l1)   

            plt.savefig("plots/init_methods_{}_{}_{}.pdf".format(gm,im,len(dataset_group)), bbox_inches="tight")
            plt.show()
