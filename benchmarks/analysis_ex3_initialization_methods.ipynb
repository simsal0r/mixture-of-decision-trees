# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_pickle("dataframes/ex3_df_initialization_methods.pd")
df
# Out:
#                    dataset  n_features  \
# 0         abalone_input.pd           8
# 1           adult_input.pd          14
# 2        banknote_input.pd           4
# 3            bank_input.pd          20
# 4   breast_cancer_input.np          10
# 5            cars_input.pd           6
# 6   contraceptive_input.pd           9
# 7      generated6_input.np           2
# 8            hrss_input.pd          18
# 9            iris_input.pd           4
# 10          steel_input.pd          27
# 11       students_input.pd          11
#
#     feature_importance_lr_max_Random_init_train  \
# 0                                      0.729463
# 1                                      0.837719
# 2                                      0.973955
# 3                                      0.908325
# 4                                      0.963800
# 5                                      0.792284
# 6                                      0.569268
# 7                                      0.872160
# 8                                      0.767395
# 9                                      0.986447
# 10                                     0.652243
# 11                                     0.543693
#
#     feature_importance_lr_max_Random_init_test  \
# 0                                     0.717692
# 1                                     0.837524
# 2                                     0.966545
# 3                                     0.906754
# 4                                     0.924783
# 5                                     0.789815
# 6                                     0.541616
# 7                                     0.866180
# 8                                     0.767207
# 9                                     0.947973
# 10                                    0.625859
# 11                                    0.477025
#
#     feature_importance_lr_max_Random_init_train_std  \
# 0                                          0.006548
# 1                                          0.005670
# 2                                          0.009557
# 3                                          0.002031
# 4                                          0.008284
# 5                                          0.015256
# 6                                          0.015834
# 7                                          0.031048
# 8                                          0.002251
# 9                                          0.007148
# 10                                         0.039376
# 11                                         0.022039
#
#     feature_importance_lr_max_Random_init_test_std  \
# 0                                         0.012734
# 1                                         0.005849
# 2                                         0.011734
# 3                                         0.002715
# 4                                         0.018329
# 5                                         0.019271
# 6                                         0.021167
# 7                                         0.033697
# 8                                         0.004301
# 9                                         0.027396
# 10                                        0.043976
# 11                                        0.044541
#
#     feature_importance_lr_max_Random_init_train_i_0  \
# 0                                          0.676987
# 1                                          0.807975
# 2                                          0.910593
# 3                                          0.897413
# 4                                          0.939110
# 5                                          0.778549
# 6                                          0.516742
# 7                                          0.741333
# 8                                          0.764069
# 9                                          0.964602
# 10                                         0.548764
# 11                                         0.516000
#
#     feature_importance_lr_max_Random_init_train_i_1  \
# 0                                          0.680817
# 1                                          0.808019
# 2                                          0.915452
# 3                                          0.897511
# 4                                          0.939110
# 5                                          0.778549
# 6                                          0.516742
# 7                                          0.739733
# 8                                          0.764069
# 9                                          0.982301
# 10                                         0.548764
# 11                                         0.516000
#
#     feature_importance_lr_max_Random_init_train_i_2  \
# 0                                          0.684966
# 1                                          0.807665
# 2                                          0.924198
# 3                                          0.897640
# 4                                          0.939110
# 5                                          0.778549
# 6                                          0.516742
# 7                                          0.739733
# 8                                          0.764069
# 9                                          0.982301
# 10                                         0.576923
# 11                                         0.516000
#
#     feature_importance_lr_max_Random_init_train_i_3  ...  \
# 0                                          0.686882  ...
# 1                                          0.806914  ...
# 2                                          0.931973  ...
# 3                                          0.897478  ...
# 4                                          0.943794  ...
# 5                                          0.778549  ...
# 6                                          0.516742  ...
# 7                                          0.739733  ...
# 8                                          0.764069  ...
# 9                                          0.982301  ...
# 10                                         0.573489  ...
# 11                                         0.516000  ...
#
#     None_BGM_init_train_i_190  None_BGM_init_train_i_191  \
# 0                    0.750080                   0.750080
# 1                    0.825745                   0.825745
# 2                    0.987366                   0.987366
# 3                    0.911139                   0.911139
# 4                    0.969555                   0.969555
# 5                    0.897377                   0.898920
# 6                    0.505882                   0.505882
# 7                    0.858933                   0.858933
# 8                    0.780647                   0.780647
# 9                    1.000000                   1.000000
# 10                   0.617445                   0.617445
# 11                   0.550000                   0.552000
#
#     None_BGM_init_train_i_192  None_BGM_init_train_i_193  \
# 0                    0.750080                   0.750080
# 1                    0.825745                   0.825745
# 2                    0.987366                   0.987366
# 3                    0.911139                   0.911139
# 4                    0.969555                   0.969555
# 5                    0.906636                   0.905864
# 6                    0.505882                   0.505882
# 7                    0.858933                   0.858933
# 8                    0.780647                   0.780647
# 9                    1.000000                   1.000000
# 10                   0.618132                   0.618132
# 11                   0.552000                   0.552000
#
#     None_BGM_init_train_i_194  None_BGM_init_train_i_195  \
# 0                    0.750080                   0.750080
# 1                    0.825745                   0.825745
# 2                    0.987366                   0.987366
# 3                    0.911139                   0.911139
# 4                    0.969555                   0.969555
# 5                    0.904321                   0.907407
# 6                    0.505882                   0.505882
# 7                    0.858933                   0.858933
# 8                    0.780647                   0.780647
# 9                    1.000000                   1.000000
# 10                   0.618132                   0.617445
# 11                   0.552000                   0.552000
#
#     None_BGM_init_train_i_196  None_BGM_init_train_i_197  \
# 0                    0.750080                   0.750080
# 1                    0.825745                   0.825745
# 2                    0.987366                   0.987366
# 3                    0.911139                   0.911139
# 4                    0.969555                   0.969555
# 5                    0.898148                   0.898148
# 6                    0.505882                   0.505882
# 7                    0.858933                   0.858933
# 8                    0.780647                   0.780647
# 9                    1.000000                   1.000000
# 10                   0.618132                   0.617445
# 11                   0.552000                   0.552000
#
#     None_BGM_init_train_i_198  None_BGM_init_train_i_199
# 0                    0.750080                   0.750080
# 1                    0.825745                   0.825745
# 2                    0.987366                   0.987366
# 3                    0.911139                   0.911139
# 4                    0.969555                   0.969555
# 5                    0.902778                   0.902778
# 6                    0.505882                   0.505882
# 7                    0.858933                   0.858933
# 8                    0.780647                   0.780647
# 9                    1.000000                   1.000000
# 10                   0.617445                   0.618132
# 11                   0.552000                   0.552000
#
# [12 rows x 1634 columns]

# %%
df.columns
# Out:
# Index(['dataset', 'n_features', 'feature_importance_lr_max_Random_init_train',
#        'feature_importance_lr_max_Random_init_test',
#        'feature_importance_lr_max_Random_init_train_std',
#        'feature_importance_lr_max_Random_init_test_std',
#        'feature_importance_lr_max_Random_init_train_i_0',
#        'feature_importance_lr_max_Random_init_train_i_1',
#        'feature_importance_lr_max_Random_init_train_i_2',
#        'feature_importance_lr_max_Random_init_train_i_3',
#        ...
#        'None_BGM_init_train_i_190', 'None_BGM_init_train_i_191',
#        'None_BGM_init_train_i_192', 'None_BGM_init_train_i_193',
#        'None_BGM_init_train_i_194', 'None_BGM_init_train_i_195',
#        'None_BGM_init_train_i_196', 'None_BGM_init_train_i_197',
#        'None_BGM_init_train_i_198', 'None_BGM_init_train_i_199'],
#       dtype='object', length=1634)

# %%
selector = ['dataset',
           'n_features',
           'feature_importance_lr_max_Random_init_test',
           'feature_importance_lr_max_Random_init_test_std',
           'feature_importance_lr_max_Random_init_train_i_0',
           'feature_importance_lr_max_Random_init_train_i_9',
           'feature_importance_lr_max_Random_init_train_i_199',
           'feature_importance_lr_max_Kmeans_init_test',
           'feature_importance_lr_max_Kmeans_init_test_std',
           'feature_importance_lr_max_Kmeans_init_train_i_0',
           'feature_importance_lr_max_Kmeans_init_train_i_9',
           'feature_importance_lr_max_Kmeans_init_train_i_199',  
           'feature_importance_lr_max_KDTmeans_init_test',
           'feature_importance_lr_max_KDTmeans_init_test_std',
           'feature_importance_lr_max_KDTmeans_init_train_i_0',
           'feature_importance_lr_max_KDTmeans_init_train_i_9',
           'feature_importance_lr_max_KDTmeans_init_train_i_199',
           'feature_importance_lr_max_BGM_init_test',
           'feature_importance_lr_max_BGM_init_test_std',
           'feature_importance_lr_max_BGM_init_train_i_0',
           'feature_importance_lr_max_BGM_init_train_i_9',
           'feature_importance_lr_max_BGM_init_train_i_199',
           'None_Random_init_test',
           'None_Random_init_test_std',
           'None_Random_init_train_i_0',
           'None_Random_init_train_i_9',
           'None_Random_init_train_i_199',
           'None_Kmeans_init_test',
           'None_Kmeans_init_test_std',
           'None_Kmeans_init_train_i_0',
           'None_Kmeans_init_train_i_9',
           'None_Kmeans_init_train_i_199',  
           'None_KDTmeans_init_test',
           'None_KDTmeans_init_test_std',
           'None_KDTmeans_init_train_i_0',
           'None_KDTmeans_init_train_i_9',
           'None_KDTmeans_init_train_i_199',
           'None_BGM_init_test',
           'None_BGM_init_test_std',
           'None_BGM_init_train_i_0',
           'None_BGM_init_train_i_9',
           'None_BGM_init_train_i_199'            
           ]

# %%
df[selector]
# Out:
#                    dataset  n_features  \
# 0         abalone_input.pd           8
# 1           adult_input.pd          14
# 2        banknote_input.pd           4
# 3            bank_input.pd          20
# 4   breast_cancer_input.np          10
# 5            cars_input.pd           6
# 6   contraceptive_input.pd           9
# 7      generated6_input.np           2
# 8            hrss_input.pd          18
# 9            iris_input.pd           4
# 10          steel_input.pd          27
# 11       students_input.pd          11
#
#     feature_importance_lr_max_Random_init_test  \
# 0                                     0.717692
# 1                                     0.837524
# 2                                     0.966545
# 3                                     0.906754
# 4                                     0.924783
# 5                                     0.789815
# 6                                     0.541616
# 7                                     0.866180
# 8                                     0.767207
# 9                                     0.947973
# 10                                    0.625859
# 11                                    0.477025
#
#     feature_importance_lr_max_Random_init_test_std  \
# 0                                         0.012734
# 1                                         0.005849
# 2                                         0.011734
# 3                                         0.002715
# 4                                         0.018329
# 5                                         0.019271
# 6                                         0.021167
# 7                                         0.033697
# 8                                         0.004301
# 9                                         0.027396
# 10                                        0.043976
# 11                                        0.044541
#
#     feature_importance_lr_max_Random_init_train_i_0  \
# 0                                          0.676987
# 1                                          0.807975
# 2                                          0.910593
# 3                                          0.897413
# 4                                          0.939110
# 5                                          0.778549
# 6                                          0.516742
# 7                                          0.741333
# 8                                          0.764069
# 9                                          0.964602
# 10                                         0.548764
# 11                                         0.516000
#
#     feature_importance_lr_max_Random_init_train_i_9  \
# 0                                          0.698691
# 1                                          0.835426
# 2                                          0.941691
# 3                                          0.897672
# 4                                          0.946136
# 5                                          0.778549
# 6                                          0.516742
# 7                                          0.740267
# 8                                          0.764069
# 9                                          0.982301
# 10                                         0.585165
# 11                                         0.538000
#
#     feature_importance_lr_max_Random_init_train_i_199  \
# 0                                            0.725184
# 1                                            0.837282
# 2                                            0.978620
# 3                                            0.909035
# 4                                            0.953162
# 5                                            0.778549
# 6                                            0.551131
# 7                                            0.811733
# 8                                            0.764069
# 9                                            0.991150
# 10                                           0.655907
# 11                                           0.538000
#
#     feature_importance_lr_max_Kmeans_init_test  \
# 0                                     0.698492
# 1                                     0.831009
# 2                                     0.967784
# 3                                     0.909651
# 4                                     0.926192
# 5                                     0.789178
# 6                                     0.529875
# 7                                     0.856900
# 8                                     0.767663
# 9                                     0.943350
# 10                                    0.580947
# 11                                    0.473572
#
#     feature_importance_lr_max_Kmeans_init_test_std  \
# 0                                         0.012824
# 1                                         0.014759
# 2                                         0.009446
# 3                                         0.002276
# 4                                         0.017692
# 5                                         0.020381
# 6                                         0.023029
# 7                                         0.018042
# 8                                         0.005065
# 9                                         0.031150
# 10                                        0.037192
# 11                                        0.045657
#
#     feature_importance_lr_max_Kmeans_init_train_i_0  ...  \
# 0                                          0.709863  ...
# 1                                          0.839935  ...
# 2                                          0.982507  ...
# 3                                          0.909067  ...
# 4                                          0.960187  ...
# 5                                          0.768519  ...
# 6                                          0.553846  ...
# 7                                          0.849600  ...
# 8                                          0.767227  ...
# 9                                          0.991150  ...
# 10                                         0.582418  ...
# 11                                         0.554000  ...
#
#     None_KDTmeans_init_test  None_KDTmeans_init_test_std  \
# 0                  0.694183                     0.015748
# 1                  0.830993                     0.018841
# 2                  0.984402                     0.007972
# 3                  0.900194                     0.007439
# 4                  0.921608                     0.024569
# 5                  0.801505                     0.018596
# 6                  0.456212                     0.026493
# 7                  0.850340                     0.012183
# 8                  0.771385                     0.005160
# 9                  0.940718                     0.034363
# 10                 0.613706                     0.040597
# 11                 0.457819                     0.041320
#
#     None_KDTmeans_init_train_i_0  None_KDTmeans_init_train_i_9  \
# 0                       0.709544                      0.710182
# 1                       0.837017                      0.836840
# 2                       0.956268                      0.966958
# 3                       0.908161                      0.908161
# 4                       0.948478                      0.962529
# 5                       0.813272                      0.813272
# 6                       0.433484                      0.433484
# 7                       0.849867                      0.850933
# 8                       0.771851                      0.771851
# 9                       0.991150                      0.991150
# 10                      0.635989                      0.648352
# 11                      0.544000                      0.544000
#
#     None_KDTmeans_init_train_i_199  None_BGM_init_test  \
# 0                         0.706352            0.708884
# 1                         0.836973            0.807692
# 2                         0.991254            0.980831
# 3                         0.908161            0.886098
# 4                         0.978923            0.921977
# 5                         0.813272            0.829456
# 6                         0.433484            0.463416
# 7                         0.855467            0.850820
# 8                         0.771851            0.772011
# 9                         0.982301            0.949289
# 10                        0.675824            0.605772
# 11                        0.544000            0.418021
#
#     None_BGM_init_test_std  None_BGM_init_train_i_0  None_BGM_init_train_i_9  \
# 0                 0.024316                 0.693584                 0.729652
# 1                 0.018108                 0.825701                 0.825701
# 2                 0.009007                 0.962099                 0.982507
# 3                 0.050181                 0.910783                 0.910977
# 4                 0.023019                 0.950820                 0.957845
# 5                 0.046436                 0.800926                 0.865741
# 6                 0.027311                 0.499548                 0.504072
# 7                 0.012796                 0.853600                 0.855467
# 8                 0.006393                 0.779350                 0.779971
# 9                 0.033813                 0.973451                 0.982301
# 10                0.036225                 0.578984                 0.592033
# 11                0.047016                 0.544000                 0.544000
#
#     None_BGM_init_train_i_199
# 0                    0.750080
# 1                    0.825745
# 2                    0.987366
# 3                    0.911139
# 4                    0.969555
# 5                    0.902778
# 6                    0.505882
# 7                    0.858933
# 8                    0.780647
# 9                    1.000000
# 10                   0.618132
# 11                   0.552000
#
# [12 rows x 42 columns]

# %%
gate_methods = ["feature_importance_lr_max" , "None"]
init_methods = ["Random_init","Kmeans_init","KDTmeans_init","BGM_init"]
datasets = df.dataset.unique()

# %%
str1 = ""
p1 = "placeholder"
for dataset in datasets:            
        for im in init_methods:
            if dataset != p1:
                str1 += "\\hline\r\n"
                str1 += "\\multirow{4}{2cm}{" + dataset.split("_")[0] +"}"
            p1 = dataset
            str1 += " & "
            str1 += im.split("_")[0] + " & "
            for gm in gate_methods: 
                column = [str(gm + "_" + im + "_test")]
                str1 += ("%.2f" % round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0")
                column = [str(gm + "_" + im + "_test_std")]
                str1 += " $\\pm$" + str(round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0") + " & "
                column = [str(gm + "_" + im + "_train_i_0")]
                str1 += ("%.2f" % round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0") + " & "
                column = [str(gm + "_" + im + "_train_i_9")]
                str1 += ("%.2f" % round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0") + " & "
                column = [str(gm + "_" + im + "_train_i_199")]
                str1 += ("%.2f" % round(df[(df["dataset"] == dataset)][column].values[0][0], 2)).lstrip("0") + " & "
            str1 = str1[:-2]
            str1 +=  "\\\\"
            str1 += "\r\n"
print(str1)
# Out:
# \hline
# \multirow{4}{2cm}{abalone} & Random & .72 $\pm$.01 & .68 & .70 & .73 & .73 $\pm$.01 & .69 & .73 & .75 \\
#  & Kmeans & .70 $\pm$.01 & .71 & .71 & .72 & .69 $\pm$.02 & .70 & .70 & .70 \\
#  & KDTmeans & .70 $\pm$.01 & .72 & .72 & .73 & .69 $\pm$.02 & .71 & .71 & .71 \\
#  & BGM & .71 $\pm$.02 & .70 & .70 & .71 & .71 $\pm$.02 & .69 & .73 & .75 \\
# \hline
# \multirow{4}{2cm}{adult} & Random & .84 $\pm$.01 & .81 & .84 & .84 & .80 $\pm$.04 & .82 & .83 & .84 \\
#  & Kmeans & .83 $\pm$.01 & .84 & .84 & .84 & .83 $\pm$.02 & .84 & .84 & .84 \\
#  & KDTmeans & .83 $\pm$.01 & .84 & .84 & .84 & .83 $\pm$.02 & .84 & .84 & .84 \\
#  & BGM & .84 $\pm$.01 & .82 & .83 & .84 & .81 $\pm$.02 & .83 & .83 & .83 \\
# \hline
# \multirow{4}{2cm}{banknote} & Random & .97 $\pm$.01 & .91 & .94 & .98 & .99 $\pm$.01 & .92 & .98 & 1.00 \\
#  & Kmeans & .97 $\pm$.01 & .98 & .98 & .98 & .99 $\pm$.01 & .96 & .97 & .99 \\
#  & KDTmeans & .97 $\pm$.01 & .97 & .96 & .98 & .98 $\pm$.01 & .96 & .97 & .99 \\
#  & BGM & .96 $\pm$.02 & .93 & .95 & .96 & .98 $\pm$.01 & .96 & .98 & .99 \\
# \hline
# \multirow{4}{2cm}{bank} & Random & .91 $\pm$.0 & .90 & .90 & .91 & .90 $\pm$.02 & .90 & .91 & .91 \\
#  & Kmeans & .91 $\pm$.0 & .91 & .91 & .91 & .90 $\pm$.01 & .91 & .91 & .91 \\
#  & KDTmeans & .91 $\pm$.0 & .91 & .91 & .91 & .90 $\pm$.01 & .91 & .91 & .91 \\
#  & BGM & .90 $\pm$.01 & .91 & .91 & .91 & .89 $\pm$.05 & .91 & .91 & .91 \\
# \hline
# \multirow{4}{2cm}{breast} & Random & .92 $\pm$.02 & .94 & .95 & .95 & .92 $\pm$.02 & .93 & .96 & .96 \\
#  & Kmeans & .93 $\pm$.02 & .96 & .96 & .97 & .92 $\pm$.02 & .96 & .96 & .98 \\
#  & KDTmeans & .93 $\pm$.02 & .95 & .95 & .96 & .92 $\pm$.02 & .95 & .96 & .98 \\
#  & BGM & .93 $\pm$.02 & .94 & .96 & .95 & .92 $\pm$.02 & .95 & .96 & .97 \\
# \hline
# \multirow{4}{2cm}{cars} & Random & .79 $\pm$.02 & .78 & .78 & .78 & .89 $\pm$.02 & .78 & .83 & .91 \\
#  & Kmeans & .79 $\pm$.02 & .77 & .77 & .77 & .80 $\pm$.02 & .81 & .81 & .81 \\
#  & KDTmeans & .79 $\pm$.02 & .77 & .77 & .77 & .80 $\pm$.02 & .81 & .81 & .81 \\
#  & BGM & .79 $\pm$.02 & .78 & .78 & .78 & .83 $\pm$.05 & .80 & .87 & .90 \\
# \hline
# \multirow{4}{2cm}{contraceptive} & Random & .54 $\pm$.02 & .52 & .52 & .55 & .52 $\pm$.03 & .54 & .58 & .56 \\
#  & Kmeans & .53 $\pm$.02 & .55 & .55 & .55 & .46 $\pm$.03 & .48 & .48 & .48 \\
#  & KDTmeans & .54 $\pm$.02 & .53 & .54 & .55 & .46 $\pm$.03 & .43 & .43 & .43 \\
#  & BGM & .54 $\pm$.02 & .55 & .55 & .55 & .46 $\pm$.03 & .50 & .50 & .51 \\
# \hline
# \multirow{4}{2cm}{generated6} & Random & .87 $\pm$.03 & .74 & .74 & .81 & .89 $\pm$.03 & .74 & .86 & .92 \\
#  & Kmeans & .86 $\pm$.02 & .85 & .85 & .85 & .85 $\pm$.01 & .85 & .85 & .86 \\
#  & KDTmeans & .86 $\pm$.02 & .85 & .85 & .89 & .85 $\pm$.01 & .85 & .85 & .86 \\
#  & BGM & .85 $\pm$.02 & .74 & .73 & .89 & .85 $\pm$.01 & .85 & .86 & .86 \\
# \hline
# \multirow{4}{2cm}{hrss} & Random & .77 $\pm$.0 & .76 & .76 & .76 & .77 $\pm$.0 & .76 & .77 & .77 \\
#  & Kmeans & .77 $\pm$.01 & .77 & .77 & .77 & .77 $\pm$.01 & .77 & .77 & .77 \\
#  & KDTmeans & .77 $\pm$.0 & .77 & .77 & .77 & .77 $\pm$.01 & .77 & .77 & .77 \\
#  & BGM & .77 $\pm$.0 & .77 & .77 & .77 & .77 $\pm$.01 & .78 & .78 & .78 \\
# \hline
# \multirow{4}{2cm}{iris} & Random & .95 $\pm$.03 & .96 & .98 & .99 & .94 $\pm$.04 & .98 & .98 & 1.00 \\
#  & Kmeans & .94 $\pm$.03 & .99 & 1.00 & 1.00 & .94 $\pm$.04 & 1.00 & 1.00 & 1.00 \\
#  & KDTmeans & .95 $\pm$.03 & .99 & .99 & .99 & .94 $\pm$.03 & .99 & .99 & .98 \\
#  & BGM & .95 $\pm$.04 & .98 & .98 & .97 & .95 $\pm$.03 & .97 & .98 & 1.00 \\
# \hline
# \multirow{4}{2cm}{steel} & Random & .63 $\pm$.04 & .55 & .59 & .66 & .67 $\pm$.02 & .55 & .67 & .71 \\
#  & Kmeans & .58 $\pm$.04 & .58 & .58 & .58 & .62 $\pm$.04 & .61 & .63 & .65 \\
#  & KDTmeans & .57 $\pm$.03 & .56 & .56 & .57 & .61 $\pm$.04 & .64 & .65 & .68 \\
#  & BGM & .62 $\pm$.04 & .58 & .58 & .63 & .61 $\pm$.04 & .58 & .59 & .62 \\
# \hline
# \multirow{4}{2cm}{students} & Random & .48 $\pm$.04 & .52 & .54 & .54 & .41 $\pm$.05 & .50 & .53 & .56 \\
#  & Kmeans & .47 $\pm$.05 & .55 & .55 & .55 & .46 $\pm$.04 & .50 & .50 & .51 \\
#  & KDTmeans & .48 $\pm$.05 & .57 & .57 & .57 & .46 $\pm$.04 & .54 & .54 & .54 \\
#  & BGM & .47 $\pm$.04 & .54 & .54 & .54 & .42 $\pm$.05 & .54 & .54 & .55 \\

# %%
df[selector]
# Out:
#                    dataset  n_features  \
# 0         abalone_input.pd           8
# 1           adult_input.pd          14
# 2        banknote_input.pd           4
# 3            bank_input.pd          20
# 4   breast_cancer_input.np          10
# 5            cars_input.pd           6
# 6   contraceptive_input.pd           9
# 7      generated6_input.np           2
# 8            hrss_input.pd          18
# 9            iris_input.pd           4
# 10          steel_input.pd          27
# 11       students_input.pd          11
#
#     feature_importance_lr_max_Random_init_test  \
# 0                                     0.717692
# 1                                     0.837524
# 2                                     0.966545
# 3                                     0.906754
# 4                                     0.924783
# 5                                     0.789815
# 6                                     0.541616
# 7                                     0.866180
# 8                                     0.767207
# 9                                     0.947973
# 10                                    0.625859
# 11                                    0.477025
#
#     feature_importance_lr_max_Random_init_test_std  \
# 0                                         0.012734
# 1                                         0.005849
# 2                                         0.011734
# 3                                         0.002715
# 4                                         0.018329
# 5                                         0.019271
# 6                                         0.021167
# 7                                         0.033697
# 8                                         0.004301
# 9                                         0.027396
# 10                                        0.043976
# 11                                        0.044541
#
#     feature_importance_lr_max_Random_init_train_i_0  \
# 0                                          0.676987
# 1                                          0.807975
# 2                                          0.910593
# 3                                          0.897413
# 4                                          0.939110
# 5                                          0.778549
# 6                                          0.516742
# 7                                          0.741333
# 8                                          0.764069
# 9                                          0.964602
# 10                                         0.548764
# 11                                         0.516000
#
#     feature_importance_lr_max_Random_init_train_i_9  \
# 0                                          0.698691
# 1                                          0.835426
# 2                                          0.941691
# 3                                          0.897672
# 4                                          0.946136
# 5                                          0.778549
# 6                                          0.516742
# 7                                          0.740267
# 8                                          0.764069
# 9                                          0.982301
# 10                                         0.585165
# 11                                         0.538000
#
#     feature_importance_lr_max_Random_init_train_i_199  \
# 0                                            0.725184
# 1                                            0.837282
# 2                                            0.978620
# 3                                            0.909035
# 4                                            0.953162
# 5                                            0.778549
# 6                                            0.551131
# 7                                            0.811733
# 8                                            0.764069
# 9                                            0.991150
# 10                                           0.655907
# 11                                           0.538000
#
#     feature_importance_lr_max_Kmeans_init_test  \
# 0                                     0.698492
# 1                                     0.831009
# 2                                     0.967784
# 3                                     0.909651
# 4                                     0.926192
# 5                                     0.789178
# 6                                     0.529875
# 7                                     0.856900
# 8                                     0.767663
# 9                                     0.943350
# 10                                    0.580947
# 11                                    0.473572
#
#     feature_importance_lr_max_Kmeans_init_test_std  \
# 0                                         0.012824
# 1                                         0.014759
# 2                                         0.009446
# 3                                         0.002276
# 4                                         0.017692
# 5                                         0.020381
# 6                                         0.023029
# 7                                         0.018042
# 8                                         0.005065
# 9                                         0.031150
# 10                                        0.037192
# 11                                        0.045657
#
#     feature_importance_lr_max_Kmeans_init_train_i_0  ...  \
# 0                                          0.709863  ...
# 1                                          0.839935  ...
# 2                                          0.982507  ...
# 3                                          0.909067  ...
# 4                                          0.960187  ...
# 5                                          0.768519  ...
# 6                                          0.553846  ...
# 7                                          0.849600  ...
# 8                                          0.767227  ...
# 9                                          0.991150  ...
# 10                                         0.582418  ...
# 11                                         0.554000  ...
#
#     None_KDTmeans_init_test  None_KDTmeans_init_test_std  \
# 0                  0.694183                     0.015748
# 1                  0.830993                     0.018841
# 2                  0.984402                     0.007972
# 3                  0.900194                     0.007439
# 4                  0.921608                     0.024569
# 5                  0.801505                     0.018596
# 6                  0.456212                     0.026493
# 7                  0.850340                     0.012183
# 8                  0.771385                     0.005160
# 9                  0.940718                     0.034363
# 10                 0.613706                     0.040597
# 11                 0.457819                     0.041320
#
#     None_KDTmeans_init_train_i_0  None_KDTmeans_init_train_i_9  \
# 0                       0.709544                      0.710182
# 1                       0.837017                      0.836840
# 2                       0.956268                      0.966958
# 3                       0.908161                      0.908161
# 4                       0.948478                      0.962529
# 5                       0.813272                      0.813272
# 6                       0.433484                      0.433484
# 7                       0.849867                      0.850933
# 8                       0.771851                      0.771851
# 9                       0.991150                      0.991150
# 10                      0.635989                      0.648352
# 11                      0.544000                      0.544000
#
#     None_KDTmeans_init_train_i_199  None_BGM_init_test  \
# 0                         0.706352            0.708884
# 1                         0.836973            0.807692
# 2                         0.991254            0.980831
# 3                         0.908161            0.886098
# 4                         0.978923            0.921977
# 5                         0.813272            0.829456
# 6                         0.433484            0.463416
# 7                         0.855467            0.850820
# 8                         0.771851            0.772011
# 9                         0.982301            0.949289
# 10                        0.675824            0.605772
# 11                        0.544000            0.418021
#
#     None_BGM_init_test_std  None_BGM_init_train_i_0  None_BGM_init_train_i_9  \
# 0                 0.024316                 0.693584                 0.729652
# 1                 0.018108                 0.825701                 0.825701
# 2                 0.009007                 0.962099                 0.982507
# 3                 0.050181                 0.910783                 0.910977
# 4                 0.023019                 0.950820                 0.957845
# 5                 0.046436                 0.800926                 0.865741
# 6                 0.027311                 0.499548                 0.504072
# 7                 0.012796                 0.853600                 0.855467
# 8                 0.006393                 0.779350                 0.779971
# 9                 0.033813                 0.973451                 0.982301
# 10                0.036225                 0.578984                 0.592033
# 11                0.047016                 0.544000                 0.544000
#
#     None_BGM_init_train_i_199
# 0                    0.750080
# 1                    0.825745
# 2                    0.987366
# 3                    0.911139
# 4                    0.969555
# 5                    0.902778
# 6                    0.505882
# 7                    0.858933
# 8                    0.780647
# 9                    1.000000
# 10                   0.618132
# 11                   0.552000
#
# [12 rows x 42 columns]

# %%
metrics = ["feature_importance_lr_max_{}_test",
           "feature_importance_lr_max_{}_train_i_0",
           "feature_importance_lr_max_{}_train_i_9",
           "feature_importance_lr_max_{}_train_i_199",
           "None_{}_test",
           "None_{}_train_i_0",
           "None_{}_train_i_9",
           "None_{}_train_i_199",
          ]

# %%
# Percentage 
df_sums = pd.DataFrame(init_methods)
for m in metrics:
    sumcolumns = []
    for im in init_methods:
        sumcolumns.append(m.format(im))
    df_sums[m] = df[selector].sum()[sumcolumns].values / df[selector].sum()[sumcolumns].values[0]   
    
df_sums
# Out:
#                0 feature_importance_lr_max_{}_test  \
# 0    Random_init                                 1
# 1    Kmeans_init                          0.989928
# 2  KDTmeans_init                          0.991787
# 3       BGM_init                          0.994357
#
#   feature_importance_lr_max_{}_train_i_0  \
# 0                                      1
# 1                                1.04482
# 2                                1.04017
# 3                                1.02021
#
#   feature_importance_lr_max_{}_train_i_9  \
# 0                                      1
# 1                                1.02749
# 2                                1.02085
# 3                                1.00651
#
#   feature_importance_lr_max_{}_train_i_199 None_{}_test None_{}_train_i_0  \
# 0                                        1            1                 1
# 1                                 0.999171     0.979107           1.02854
# 2                                  1.00366     0.976592           1.02982
# 3                                  1.00072     0.973542           1.02694
#
#   None_{}_train_i_9 None_{}_train_i_199
# 0                 1                   1
# 1          0.980941            0.960733
# 2          0.982089            0.960641
# 3           0.99172            0.977268

# %%
# Percentage points diff
df_sums = pd.DataFrame(init_methods)
for m in metrics:
    sumcolumns = []
    for im in init_methods:
        sumcolumns.append(m.format(im))
    df_sums[m] = df[selector].sum()[sumcolumns].values - df[selector].sum()[sumcolumns].values[0]   
    
df_sums
# Out:
#                0 feature_importance_lr_max_{}_test  \
# 0    Random_init                                 0
# 1    Kmeans_init                        -0.0943596
# 2  KDTmeans_init                        -0.0769475
# 3       BGM_init                         -0.052871
#
#   feature_importance_lr_max_{}_train_i_0  \
# 0                                      0
# 1                               0.406182
# 2                               0.364033
# 3                               0.183131
#
#   feature_importance_lr_max_{}_train_i_9  \
# 0                                      0
# 1                               0.253619
# 2                               0.192319
# 3                              0.0600208
#
#   feature_importance_lr_max_{}_train_i_199 None_{}_test None_{}_train_i_0  \
# 0                                        0            0                 0
# 1                              -0.00786689    -0.197314          0.260447
# 2                                0.0347717     -0.22107          0.272125
# 3                               0.00685381    -0.249868           0.24589
#
#   None_{}_train_i_9 None_{}_train_i_199
# 0                 0                   0
# 1         -0.183153           -0.388235
# 2         -0.172125           -0.389147
# 3        -0.0795709           -0.224749

# %%
# Percentage diff
df_sums = pd.DataFrame(init_methods)
for m in metrics:
    sumcolumns = []
    for im in init_methods:
        sumcolumns.append(m.format(im))
    df_sums[m] = df[selector].sum()[sumcolumns].values / df[selector].sum()[sumcolumns].values[0] - 1  
    
df_sums
# Out:
#                0 feature_importance_lr_max_{}_test  \
# 0    Random_init                                 0
# 1    Kmeans_init                        -0.0100715
# 2  KDTmeans_init                       -0.00821302
# 3       BGM_init                        -0.0056432
#
#   feature_importance_lr_max_{}_train_i_0  \
# 0                                      0
# 1                              0.0448218
# 2                              0.0401707
# 3                              0.0202083
#
#   feature_importance_lr_max_{}_train_i_9  \
# 0                                      0
# 1                              0.0274935
# 2                              0.0208483
# 3                             0.00650653
#
#   feature_importance_lr_max_{}_train_i_199 None_{}_test None_{}_train_i_0  \
# 0                                        0            0                 0
# 1                             -0.000828633   -0.0208928          0.028536
# 2                               0.00366256   -0.0234081         0.0298155
# 3                              0.000721923   -0.0264575         0.0269411
#
#   None_{}_train_i_9 None_{}_train_i_199
# 0                 0                   0
# 1        -0.0190589          -0.0392671
# 2        -0.0179114          -0.0393594
# 3       -0.00828015          -0.0227318

# %%
str1 = "\\hline\r\n"
str1 += "\\multirow{4}{2cm}{" + "average percentage difference" +"}"
for index, row in df_sums.iterrows():
    for element in row:
        if type(element) == str: 
            str1 += " & " + element.split("_")[0] + " & "
        else:
            str1 += ("%.2f" % round(element, 2)).replace("0.",".") + " & "
    str1 = str1[:-2]        
    str1 +=  "\\\\"
    str1 += "\r\n"
    
print(str1)
# Out:
# \hline
# \multirow{4}{2cm}{average percentage difference} & Random & .00 & .00 & .00 & .00 & .00 & .00 & .00 & .00 \\
#  & Kmeans & -.01 & .04 & .03 & -.00 & -.02 & .03 & -.02 & -.04 \\
#  & KDTmeans & -.01 & .04 & .02 & .00 & -.02 & .03 & -.02 & -.04 \\
#  & BGM & -.01 & .02 & .01 & .00 & -.03 & .03 & -.01 & -.02 \\

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
plt.style.use('ggplot')
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['font.size'] = 12

COLOR = 'black'
plt.rcParams['text.color'] = COLOR
plt.rcParams['axes.labelcolor'] = COLOR
plt.rcParams['xtick.color'] = COLOR

# %%
gate_methods = ["feature_importance_lr_max" , "None"]
init_methods = ["Random_init","Kmeans_init","KDTmeans_init","BGM_init"]

# %%
df.dataset.unique()
# Out:
# array(['abalone_input.pd', 'adult_input.pd', 'banknote_input.pd',
#        'bank_input.pd', 'breast_cancer_input.np', 'cars_input.pd',
#        'contraceptive_input.pd', 'generated6_input.np', 'hrss_input.pd',
#        'iris_input.pd', 'steel_input.pd', 'students_input.pd'],
#       dtype=object)

# %%
datasets1 = [
             'iris_input.pd',
             'breast_cancer_input.np',
             'cars_input.pd',
             'abalone_input.pd',
             'steel_input.pd',
             'students_input.pd',
]
datasets2 = [
             'contraceptive_input.pd',
             'banknote_input.pd',
             'generated6_input.np',
             'bank_input.pd',
             'adult_input.pd',
             'hrss_input.pd',
]

# %%
colormap = { 
    'iris_input.pd': "#8EBA42",
    'breast_cancer_input.np' : "#FBC15E" ,
    'cars_input.pd' : "#B97357",
    'abalone_input.pd': "#348ABD",
    'steel_input.pd': "#988ED5",
    'students_input.pd' : "#81D0DB",

    'contraceptive_input.pd' : "#E24A33" ,
    'banknote_input.pd' : "#81D0DB",
    'generated6_input.np' : "#FBC15E",
    'bank_input.pd' : "#8EBA42",
    'adult_input.pd' :"#E24A33",
    'hrss_input.pd' : "#988ED5",
}

# %%
for dataset_group in [datasets1, datasets2]:
    displayed_iterations=100
    fig = plt.gcf()
    fig.set_size_inches(10, 4)
    iterations = np.arange(displayed_iterations)
    for dataset in dataset_group:
        accuracies = []
        for i in range(displayed_iterations):
            accuracies.append(df[df.dataset == dataset]["feature_importance_lr_max_Random_init_train_i_" + str(i)].values[0])
        plt.plot(iterations,accuracies,linewidth=1,linestyle='--',color=colormap[dataset])
        accuracies = []
        for i in range(displayed_iterations):
            accuracies.append(df[df.dataset == dataset]["feature_importance_lr_max_BGM_init_train_i_" + str(i)].values[0])
        plt.plot(iterations,accuracies,linewidth=1,linestyle='-',color=colormap[dataset],label=dataset.split("_")[0])
    plt.ylabel("training accuracy", fontsize=12)
    plt.xlabel("iteration", fontsize=12)
    l1 = plt.legend(bbox_to_anchor=(1, 1.02), loc="upper left")

    legend_elements = [Line2D([0], [0], color='grey', linestyle='-', label='initialization'),
                       Line2D([0], [0], color='grey', linestyle='--', label='random')]
    ax = plt.gca()
    ax.legend(handles=legend_elements, bbox_to_anchor=(1, -0.02), loc="lower left")
    ax.add_artist(l1)   
    
    #plt.savefig("plots/test.pdf", bbox_inches="tight")
    plt.show()
                                                    #

# %%
def translator(word):
    if word == "feature_importance_lr_max":
        return "2D "
    elif word == "None":
        return "f. "
    else:
        return "error"

# %%
# Save all
for gm in gate_methods:
    for im in init_methods:
        for dataset_group in [datasets1, datasets2]:
            displayed_iterations=100
            fig = plt.gcf()
            fig.set_size_inches(4.65, 3.3)
            iterations = np.arange(displayed_iterations)
            for dataset in dataset_group:
                accuracies = []
                for i in range(displayed_iterations):
                    accuracies.append(df[df.dataset == dataset]["{}_Random_init_train_i_".format(gm) + str(i)].values[0])
                plt.plot(iterations,accuracies,linewidth=1.5,linestyle='--',color=colormap[dataset])
                accuracies = []
                for i in range(displayed_iterations):
                    accuracies.append(df[df.dataset == dataset]["{}_{}_train_i_".format(gm,im) + str(i)].values[0])
                plt.plot(iterations,accuracies,linewidth=1.5,linestyle='-',color=colormap[dataset],label=dataset.split("_")[0])
            plt.ylabel("training accuracy", fontsize=12)
            plt.xlabel("iteration", fontsize=12)
            l1 = plt.legend(bbox_to_anchor=(1, 1.02), loc="upper left")

            legend_elements = [Line2D([0], [0], color='grey', linestyle='-', label=translator(gm) + im.split("_")[0] ),
                               Line2D([0], [0], color='grey', linestyle='--', label=translator(gm) + "random")]
            ax = plt.gca()
            ax.legend(handles=legend_elements, bbox_to_anchor=(1, -0.02), loc="lower left")
            ax.add_artist(l1)   

            plt.savefig("plots/init_methods_{}_{}_{}.pdf".format(gm,im,str(dataset_group[0])), bbox_inches="tight")
            plt.show()
