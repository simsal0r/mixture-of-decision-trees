# %%
import pandas as pd
import numpy as np
import optuna

# %%
loaded_study = optuna.load_study(study_name="2021.06.14 13:09:54 learning_rate", storage="sqlite:///optuna_results.sqlite3")

# %%
loaded_study.system_attrs
# Out:
# {'Data X': 'datasets/generated6_input.np',
#  'Data y': 'datasets/generated6_target.np',
#  'X': 'None',
#  'add_noise': 'False',
#  'black_box_algorithm': 'None',
#  'class_names': 'None',
#  'feature_names': 'None',
#  'init_learning_rate': 'None',
#  'initialization_method': 'None',
#  'initialize_with': 'random',
#  'iterations': '150',
#  'learning_rate_decay': '1',
#  'max_depth': '2',
#  'n_experts': '3',
#  'optimization_method': 'least_squares_linear_regression',
#  'use_2_dim_clustering': 'False',
#  'use_2_dim_gate_based_on': 'None',
#  'use_posterior': 'False',
#  'y': 'None'}

# %%
loaded_study.best_trial
# Out:
# FrozenTrial(number=48, values=[0.9425000000000001], datetime_start=datetime.datetime(2021, 6, 14, 13, 21, 21, 771433), datetime_complete=datetime.datetime(2021, 6, 14, 13, 21, 43, 53932), params={'init_learning_rate': 68.02512294903094, 'learning_rate_decay': 0.9973583101226295}, distributions={'init_learning_rate': UniformDistribution(high=300.0, low=10.0), 'learning_rate_decay': UniformDistribution(high=0.999, low=0.9)}, user_attrs={'completed_iterations': 149.6, 'train_score': 0.95059375, 'train_score_i_0': 0.71890625, 'train_score_i_9': 0.9157187499999999}, system_attrs={}, intermediate_values={}, trial_id=99, state=TrialState.COMPLETE, value=None)

# %%
df = loaded_study.trials_dataframe()
df
# Out:
#     number     value             datetime_start          datetime_complete  \
# 0        0  0.898625 2021-06-14 13:09:55.907940 2021-06-14 13:10:11.311571
# 1        1  0.904250 2021-06-14 13:10:11.439608 2021-06-14 13:10:24.951424
# 2        2  0.903125 2021-06-14 13:10:25.072424 2021-06-14 13:10:39.782321
# 3        3  0.935250 2021-06-14 13:10:39.890327 2021-06-14 13:10:54.695711
# 4        4  0.888000 2021-06-14 13:10:54.820708 2021-06-14 13:11:07.756334
# 5        5  0.905250 2021-06-14 13:11:07.875394 2021-06-14 13:11:21.015418
# 6        6  0.920625 2021-06-14 13:11:21.133418 2021-06-14 13:11:35.844042
# 7        7  0.919500 2021-06-14 13:11:35.964043 2021-06-14 13:11:47.906041
# 8        8  0.911250 2021-06-14 13:11:48.014040 2021-06-14 13:11:58.969041
# 9        9  0.919625 2021-06-14 13:11:59.096057 2021-06-14 13:12:13.111541
# 10      10  0.928125 2021-06-14 13:12:13.225599 2021-06-14 13:12:28.028890
# ...
