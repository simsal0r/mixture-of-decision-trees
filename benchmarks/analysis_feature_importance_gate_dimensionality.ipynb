# %%
import pickle
import pandas as pd
import numpy as np

# %%
df = pd.read_pickle("dataframes/df_fi_performance.pd")

# %%
df
# Out:
#                    dataset  n_features  feature_importance_train  \
# 0   breast_cancer_input.np          10                  0.968630
# 1            iris_input.pd           4                  0.989000
# 2           steel_input.pd          27                  0.650410
# 3         abalone_input.pd           8                  0.729399
# 4   contraceptive_input.pd           9                  0.588256
# 5            cars_input.pd           6                  0.807753
# 6        students_input.pd          11                  0.526726
# 7           adult_input.pd          14                  0.832427
# 8            bank_input.pd          20                  0.908623
# 9            hrss_input.pd          18                  0.770057
# 10      occupancy_input.pd           5                  0.992460
# 11           pdm6_input.pd           6                  0.974670
# 12       banknote_input.pd           4                  0.982726
#
#     feature_importance_test  feature_importance_train_std  \
# 0                  0.923372                      0.006036
# 1                  0.954667                      0.007717
# 2                  0.625977                      0.022587
# 3                  0.714771                      0.008493
# 4                  0.559120                      0.010739
# 5                  0.799540                      0.010381
# 6                  0.442940                      0.015762
# 7                  0.830854                      0.007232
# 8                  0.905618                      0.001798
# 9                  0.768974                      0.002860
# 10                 0.990863                      0.000998
# 11                 0.972380                      0.001224
# 12                 0.969968                      0.006094
#
#     feature_importance_test_std  feature_importance_lda_train  \
# 0                      0.019843                      0.961509
# 1                      0.039866                      0.990000
# 2                      0.026080                      0.614323
# 3                      0.019370                      0.736234
# 4                      0.030638                      0.588731
# 5                      0.020234                      0.812762
# 6                      0.044709                      0.542864
# 7                      0.012971                      0.838988
# 8                      0.005544                      0.909147
# 9                      0.004254                      0.769736
# 10                     0.001945                      0.989402
# 11                     0.003389                      0.974505
# 12                     0.009648                      0.996538
#
#     feature_importance_lda_test  feature_importance_lda_train_std  \
# 0                      0.911405                          0.007899
# 1                      0.953333                          0.007071
# 2                      0.588662                          0.014126
# 3                      0.725261                          0.005833
# 4                      0.553973                          0.009665
# 5                      0.798964                          0.010612
# 6                      0.470214                          0.016213
# 7                      0.836152                          0.002242
# 8                      0.905317                          0.001873
# 9                      0.769380                          0.003011
# 10                     0.988235                          0.000764
# 11                     0.971860                          0.001053
# 12                     0.991253                          0.003207
#
#     feature_importance_lda_test_std  ...  \
# 0                          0.025404  ...
# 1                          0.037712  ...
# 2                          0.022501  ...
# 3                          0.014677  ...
# 4                          0.030842  ...
# 5                          0.018924  ...
# 6                          0.053004  ...
# 7                          0.010774  ...
# 8                          0.010726  ...
# 9                          0.006642  ...
# 10                         0.002461  ...
# 11                         0.003257  ...
# 12                         0.008253  ...
#
#     feature_importance_pca_loadings_train_std  \
# 0                                    0.006086
# 1                                    0.009638
# 2                                    0.020422
# 3                                    0.008828
# 4                                    0.018568
# 5                                    0.015722
# 6                                    0.014247
# 7                                    0.007203
# 8                                    0.001518
# 9                                    0.002579
# 10                                   0.001101
# 11                                   0.001496
# 12                                   0.016142
#
#     feature_importance_pca_loadings_test_std  PCA_train  PCA_test  \
# 0                                   0.018309   0.960369  0.915616
# 1                                   0.033307   0.989000  0.940000
# 2                                   0.036981   0.629235  0.607110
# 3                                   0.014018   0.705004  0.683600
# 4                                   0.029537   0.544433  0.512969
# 5                                   0.028717   0.806451  0.797108
# 6                                   0.049396   0.521398  0.459495
# 7                                   0.022606   0.841751  0.829912
# 8                                   0.003303   0.907231  0.904953
# 9                                   0.006561   0.770960  0.770133
# 10                                  0.002596   0.990126  0.988726
# 11                                  0.004017   0.973260  0.971300
# 12                                  0.022824   0.985861  0.974929
#
#     PCA_train_std  PCA_test_std  None_train  None_test  None_train_std  \
# 0        0.006352      0.024205    0.984797   0.924782        0.003287
# 1        0.006549      0.045216    0.996000   0.948000        0.004163
# 2        0.020900      0.020661    0.718959   0.669451        0.019072
# 3        0.006808      0.015481    0.754812   0.736705        0.005301
# 4        0.012233      0.022512    0.585779   0.512692        0.011777
# 5        0.016857      0.029606    0.906569   0.889819        0.018991
# 6        0.012225      0.038333    0.616966   0.408500        0.026309
# 7        0.002819      0.013310    0.850786   0.785212        0.002895
# 8        0.000725      0.002733    0.912359   0.895946        0.001736
# 9        0.001901      0.006597    0.776041   0.774794        0.004632
# 10       0.000995      0.002330    0.993528   0.991084        0.001049
# 11       0.001977      0.003688    0.983325   0.979820        0.002142
# 12       0.004016      0.008513    0.999198   0.997522        0.001133
#
#     None_test_std
# 0        0.026429
# 1        0.041183
# 2        0.028620
# 3        0.013200
# 4        0.024392
# 5        0.020058
# 6        0.057937
# 7        0.033562
# 8        0.019571
# 9        0.005286
# 10       0.002589
# 11       0.003190
# 12       0.003373
#
# [13 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['dataset', 'n_features', 'feature_importance_train',
#        'feature_importance_test', 'feature_importance_train_std',
#        'feature_importance_test_std', 'feature_importance_lda_train',
#        'feature_importance_lda_test', 'feature_importance_lda_train_std',
#        'feature_importance_lda_test_std', 'feature_importance_lda_max_train',
#        'feature_importance_lda_max_test',
#        'feature_importance_lda_max_train_std',
#        'feature_importance_lda_max_test_std', 'feature_importance_lr_train',
#        'feature_importance_lr_test', 'feature_importance_lr_train_std',
#        'feature_importance_lr_test_std', 'feature_importance_lr_max_train',
#        'feature_importance_lr_max_test', 'feature_importance_lr_max_train_std',
#        'feature_importance_lr_max_test_std', 'feature_importance_xgb_train',
#        'feature_importance_xgb_test', 'feature_importance_xgb_train_std',
#        'feature_importance_xgb_test_std',
#        'feature_importance_pca_loadings_train',
#        'feature_importance_pca_loadings_test',
#        'feature_importance_pca_loadings_train_std',
#        'feature_importance_pca_loadings_test_std', 'PCA_train', 'PCA_test',
#        'PCA_train_std', 'PCA_test_std', 'None_train', 'None_test',
#        'None_train_std', 'None_test_std'],
#       dtype='object')

# %%
def printer(row, name):
    test = name + "_test"
    std = name + "_test_std"
    return "" + ("%.2f" % round(row[test], 2)).lstrip("0") + " $\\pm$" + ("%.2f" % round(row[std], 2)).lstrip("0") + " & "

# %%
for index, row in df.iterrows():
    str1 = row.dataset.split("_")[0] + " & "    
   # str1 += str(row.n_features - 1) + "& "
    str1 += printer(row,"feature_importance")
    str1 += printer(row,"feature_importance_lda")
    str1 += printer(row,"feature_importance_lda_max")
    str1 += printer(row,"feature_importance_lr")
    str1 += printer(row,"feature_importance_lr_max")
    str1 += printer(row,"feature_importance_xgb")
    str1 += printer(row,"feature_importance_pca_loadings")        
#    str1 += printer(row,"PCA")
#    str1 += printer(row,"None")
    str1 = str1[:-2]
    str1 +=  "\\\\"
    print(str1)
# Out:
# breast & .92 $\pm$.02 & .91 $\pm$.03 & .92 $\pm$.02 & .93 $\pm$.02 & .93 $\pm$.03 & .93 $\pm$.02 & .92 $\pm$.02 \\
# iris & .95 $\pm$.04 & .95 $\pm$.04 & .94 $\pm$.05 & .95 $\pm$.04 & .95 $\pm$.03 & .95 $\pm$.03 & .93 $\pm$.03 \\
# steel & .63 $\pm$.03 & .59 $\pm$.02 & .59 $\pm$.03 & .60 $\pm$.03 & .66 $\pm$.03 & .57 $\pm$.04 & .60 $\pm$.04 \\
# abalone & .71 $\pm$.02 & .73 $\pm$.01 & .72 $\pm$.01 & .73 $\pm$.01 & .72 $\pm$.02 & .71 $\pm$.01 & .69 $\pm$.01 \\
# contraceptive & .56 $\pm$.03 & .55 $\pm$.03 & .57 $\pm$.03 & .56 $\pm$.03 & .55 $\pm$.02 & .55 $\pm$.02 & .48 $\pm$.03 \\
# cars & .80 $\pm$.02 & .80 $\pm$.02 & .78 $\pm$.02 & .79 $\pm$.02 & .79 $\pm$.02 & .79 $\pm$.02 & .79 $\pm$.03 \\
# students & .44 $\pm$.04 & .47 $\pm$.05 & .46 $\pm$.06 & .48 $\pm$.06 & .48 $\pm$.06 & .47 $\pm$.04 & .46 $\pm$.05 \\
# adult & .83 $\pm$.01 & .84 $\pm$.01 & .84 $\pm$.01 & .84 $\pm$.00 & .84 $\pm$.01 & .84 $\pm$.01 & .82 $\pm$.02 \\
# bank & .91 $\pm$.01 & .91 $\pm$.01 & .90 $\pm$.01 & .91 $\pm$.01 & .90 $\pm$.02 & .91 $\pm$.00 & .91 $\pm$.00 \\
# hrss & .77 $\pm$.00 & .77 $\pm$.01 & .77 $\pm$.01 & .77 $\pm$.00 & .77 $\pm$.01 & .77 $\pm$.01 & .77 $\pm$.01 \\
# occupancy & .99 $\pm$.00 & .99 $\pm$.00 & .99 $\pm$.00 & .99 $\pm$.00 & .99 $\pm$.00 & .99 $\pm$.00 & .99 $\pm$.00 \\
# pdm6 & .97 $\pm$.00 & .97 $\pm$.00 & .97 $\pm$.00 & .97 $\pm$.00 & .97 $\pm$.00 & .97 $\pm$.00 & .97 $\pm$.00 \\
# banknote & .97 $\pm$.01 & .99 $\pm$.01 & .99 $\pm$.01 & .97 $\pm$.01 & .97 $\pm$.01 & .97 $\pm$.01 & .96 $\pm$.02 \\

# %%
# Best val acc vs PCA and None

# %%
comparison = ["feature_importance",
"feature_importance_lda",
"feature_importance_lda_max",
"feature_importance_lr",
"feature_importance_lr_max",
"feature_importance_xgb",
"feature_importance_pca_loadings"]

# %%
test_acc = [x + "_test" for x in comparison]

# %%
df[test_acc]
# Out:
#     feature_importance_test  feature_importance_lda_test  \
# 0                  0.923372                     0.911405
# 1                  0.954667                     0.953333
# 2                  0.625977                     0.588662
# 3                  0.714771                     0.725261
# 4                  0.559120                     0.553973
# 5                  0.799540                     0.798964
# 6                  0.442940                     0.470214
# 7                  0.830854                     0.836152
# 8                  0.905618                     0.905317
# 9                  0.768974                     0.769380
# 10                 0.990863                     0.988235
# 11                 0.972380                     0.971860
# 12                 0.969968                     0.991253
#
#     feature_importance_lda_max_test  feature_importance_lr_test  \
# 0                          0.915640                    0.925471
# 1                          0.942667                    0.952000
# 2                          0.587946                    0.598463
# 3                          0.720469                    0.728276
# 4                          0.566179                    0.562398
# 5                          0.777313                    0.788427
# 6                          0.464298                    0.481174
# 7                          0.836424                    0.838532
# 8                          0.902913                    0.907026
# 9                          0.770235                    0.768365
# 10                         0.988309                    0.990127
# 11                         0.972300                    0.972720
# 12                         0.991694                    0.974640
#
#     feature_importance_lr_max_test  feature_importance_xgb_test  \
# 0                         0.925490                     0.927961
# 1                         0.954667                     0.954667
# 2                         0.662227                     0.568674
# 3                         0.719416                     0.711325
# 4                         0.551244                     0.553159
# 5                         0.787963                     0.794446
# 6                         0.476966                     0.471155
# 7                         0.835714                     0.836994
# 8                         0.900034                     0.906177
# 9                         0.768137                     0.771114
# 10                        0.990863                     0.989365
# 11                        0.972200                     0.972240
# 12                        0.973761                     0.974780
#
#     feature_importance_pca_loadings_test
# 0                               0.920904
# 1                               0.932000
# 2                               0.601440
# 3                               0.689964
# 4                               0.479026
# 5                               0.791661
# 6                               0.463710
# 7                               0.819356
# 8                               0.905739
# 9                               0.767909
# 10                              0.990348
# 11                              0.970660
# 12                              0.956993

# %%
highs = df[test_acc].idxmax(axis=1)
highs
# Out:
# 0         feature_importance_xgb_test
# 1         feature_importance_xgb_test
# 2      feature_importance_lr_max_test
# 3          feature_importance_lr_test
# 4     feature_importance_lda_max_test
# 5             feature_importance_test
# 6          feature_importance_lr_test
# 7          feature_importance_lr_test
# 8          feature_importance_lr_test
# 9         feature_importance_xgb_test
# 10     feature_importance_lr_max_test
# 11         feature_importance_lr_test
# 12    feature_importance_lda_max_test
# dtype: object

# %%
str1 = ""
for index, row in df.iterrows():
    str1 += row.dataset.split("_")[0] + " & "
    str1 += str(row.n_features) + " & "
    str1 += highs[index].rstrip("_test") + " & "
    str1 += str("%.2f" % round(row[highs[index]], 2)).lstrip("0") 
    std_name = str(highs[index]) + "_std"
    str1 += " $\\pm$" + str("%.2f" % round(row[std_name], 2)).lstrip("0") + " & "
    #str1 += str(row[highs[index]])
    str1 += printer(row, "PCA")
    str1 += printer(row, "None")
    str1 = str1[:-2]
    str1 +=  "\\\\ \r\n"
print(str1)
# Out:
# breast & 10 & feature_importance_xgb & .93 $\pm$.02 & .92 $\pm$.02 & .92 $\pm$.03 \\
# iris & 4 & feature_importance_xgb & .95 $\pm$.03 & .94 $\pm$.05 & .95 $\pm$.04 \\
# steel & 27 & feature_importance_lr_max & .66 $\pm$.03 & .61 $\pm$.02 & .67 $\pm$.03 \\
# abalone & 8 & feature_importance_lr & .73 $\pm$.01 & .68 $\pm$.02 & .74 $\pm$.01 \\
# contraceptive & 9 & feature_importance_lda_max & .57 $\pm$.03 & .51 $\pm$.02 & .51 $\pm$.02 \\
# cars & 6 & feature_importanc & .80 $\pm$.02 & .80 $\pm$.03 & .89 $\pm$.02 \\
# students & 11 & feature_importance_lr & .48 $\pm$.06 & .46 $\pm$.04 & .41 $\pm$.06 \\
# adult & 14 & feature_importance_lr & .84 $\pm$.00 & .83 $\pm$.01 & .79 $\pm$.03 \\
# bank & 20 & feature_importance_lr & .91 $\pm$.01 & .90 $\pm$.00 & .90 $\pm$.02 \\
# hrss & 18 & feature_importance_xgb & .77 $\pm$.01 & .77 $\pm$.01 & .77 $\pm$.01 \\
# occupancy & 5 & feature_importance_lr_max & .99 $\pm$.00 & .99 $\pm$.00 & .99 $\pm$.00 \\
# pdm6 & 6 & feature_importance_lr & .97 $\pm$.00 & .97 $\pm$.00 & .98 $\pm$.00 \\
# banknote & 4 & feature_importance_lda_max & .99 $\pm$.01 & .97 $\pm$.01 & 1.00 $\pm$.00 \\

# %%
str1 = ""
for sum_deviation in round(df[test_acc].sum() - df[test_acc].sum().max(),2):
    str1 += str(sum_deviation) + " & "
print(str1)
# Out:
# -0.06 & -0.05 & -0.08 & -0.03 & 0.0 & -0.09 & -0.23 &

# %%
df[test_acc].sum().max()
# Out:
# 10.51868078359849
